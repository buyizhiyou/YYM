# %% [markdown]
# # 1. Define Concrete Dropout and Variational Dropout

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class ConcreteDropout(nn.Module):
    def __init__(self, p_logit=-2.0, temp=0.01, eps=1e-8):
        super(ConcreteDropout, self).__init__()
        self.p_logit = nn.Parameter(torch.Tensor([p_logit]))
        self.temp = temp
        self.eps = eps

    @property
    def p(self):
        return torch.sigmoid(self.p_logit)

    def forward(self, x):
        if self.train():
            unif_noise = torch.rand_like(x)
            drop_prob = (
                torch.log(self.p + self.eps)
                - torch.log(1 - self.p + self.eps)
                + torch.log(unif_noise + self.eps)
                - torch.log(1 - unif_noise + self.eps)
            )
            drop_prob = torch.sigmoid(drop_prob / self.temp)
            random_tensor = 1.0 - drop_prob
            retain_prob = 1.0 - self.p
            x *= random_tensor
            x /= retain_prob
        return x

# %%
cdrop = ConcreteDropout()
drop = nn.Dropout(p=0.1)
input = torch.ones([1, 10])
output1 = cdrop(input)
input = torch.ones([1, 10])
output2 = drop(input)
print(output1)
print(output2)
# Out:
# tensor([[1.1353, 1.1353, 0.0000, 1.1353, 1.1353, 1.1353, 1.1353, 1.1353, 0.0000,
#          1.1353]], grad_fn=<DivBackward0>)
# tensor([[1.1111, 1.1111, 1.1111, 1.1111, 1.1111, 1.1111, 1.1111, 0.0000, 0.0000,
#          1.1111]])

# %%
class VariationalDropout(nn.Module):
    def __init__(self, log_alpha=-3.0):
        super(VariationalDropout, self).__init__()
        self.max_log_alpha = 0.0
        self.log_alpha = nn.Parameter(torch.Tensor([log_alpha]))

    @property
    def alpha(self):
        return torch.exp(self.log_alpha)

    def forward(self, x):
        if self.train():
            normal_noise = torch.randn_like(x)
            self.log_alpha.data = torch.clamp(
                self.log_alpha.data, max=self.max_log_alpha
            )
            random_tensor = 1.0 + normal_noise * torch.sqrt(self.alpha)
            x *= random_tensor
        return x

# %% [markdown]
# # 2. Loading and normalizing CIFAR-10

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
batch_size = 1000

train_transform = transforms.Compose(
    [
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ]
)

test_transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ]
)

trainset = torchvision.datasets.CIFAR10(
    root="../data", train=True, download=True, transform=train_transform
)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=4
)

testset = torchvision.datasets.CIFAR10(
    root="../data", train=False, download=True, transform=test_transform
)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=4
)

classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)
print("train set size: {}".format(len(trainset)))
log_freq = len(trainset) // batch_size
print("log freq: {}".format(log_freq))
print("test set size: {}".format(len(testset)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train set size: 50000
# log freq: 50
# test set size: 10000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(images.shape)

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(" ".join("%5s" % classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([1000, 3, 32, 32])
#   car  deer plane  frog

# %% [markdown]
# # 3. Define Lenet with/without dropout

# %%
# Lenet with Concrete dropout
class Net_CDO(nn.Module):
    def __init__(self, weight_reg_coef=5e-4, dropout_reg_coef=1e-2):
        super(Net_CDO, self).__init__()
        self.conv1 = nn.Conv2d(3, 192, 5, padding=2)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(192, 192, 5, padding=2)
        self.fc1 = nn.Linear(192 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 10)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.cdropout1 = ConcreteDropout()
        self.cdropout2 = ConcreteDropout()
        self.cdropout3 = ConcreteDropout()
        self.cdropout4 = ConcreteDropout()
        self.weight_reg_coef = weight_reg_coef
        self.dropout_reg_coef = dropout_reg_coef

        nn.init.xavier_uniform_(self.conv1.weight)
        nn.init.constant_(self.conv1.bias, 0.0)
        nn.init.xavier_uniform_(self.conv2.weight)
        nn.init.constant_(self.conv2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.constant_(self.fc1.bias, 0.0)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.constant_(self.fc2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.constant_(self.fc3.bias, 0.0)

    def forward(self, x):
        x = self.pool(self.leaky_relu(self.cdropout1(self.conv1(x))))
        x = self.pool(self.leaky_relu(self.cdropout2(self.conv2(x))))
        x = x.view(-1, 192 * 8 * 8)
        x = self.leaky_relu(self.cdropout3(self.fc1(x)))
        x = self.leaky_relu(self.cdropout4(self.fc2(x)))
        x = F.softmax(self.fc3(x), dim=1)
        return x

    def entropy(self, cdropout):
        return -cdropout.p * torch.log(cdropout.p + 1e-8) - (
            1 - cdropout.p
        ) * torch.log(1 - cdropout.p + 1e-8)

    def calc_reg(self):
        weight_reg = (
            (self.fc1.weight.norm() ** 2 + self.fc1.bias.norm() ** 2)
            / (1 - self.cdropout3.p)
            + (self.fc2.weight.norm() ** 2 + self.fc2.bias.norm() ** 2)
            / (1 - self.cdropout4.p)
            + (self.fc3.weight.norm() ** 2 + self.fc3.bias.norm() ** 2)
            + (self.conv1.weight.norm() ** 2 + self.conv1.bias.norm() ** 2)
            / (1 - self.cdropout1.p)
            + (self.conv2.weight.norm() ** 2 + self.conv2.bias.norm() ** 2)
            / (1 - self.cdropout2.p)
        )
        weight_reg *= self.weight_reg_coef
        dropout_reg = (
            -self.entropy(self.cdropout1)
            - self.entropy(self.cdropout2)
            - self.entropy(self.cdropout3)
            - self.entropy(self.cdropout4)
        )
        dropout_reg *= self.dropout_reg_coef
        return weight_reg + dropout_reg


# Lenet with Variational dropout
class Net_VDO(nn.Module):
    def __init__(self, reg_coef=5e-4):
        super(Net_VDO, self).__init__()
        self.conv1 = nn.Conv2d(3, 192, 5, padding=2)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(192, 192, 5, padding=2)
        self.fc1 = nn.Linear(192 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 10)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.vdropout1 = VariationalDropout()
        self.vdropout2 = VariationalDropout()
        self.vdropout3 = VariationalDropout()
        self.vdropout4 = VariationalDropout()
        self.reg_coef = reg_coef

        nn.init.xavier_uniform_(self.conv1.weight)
        nn.init.constant_(self.conv1.bias, 0.0)
        nn.init.xavier_uniform_(self.conv2.weight)
        nn.init.constant_(self.conv2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.constant_(self.fc1.bias, 0.0)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.constant_(self.fc2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.constant_(self.fc3.bias, 0.0)

    def forward(self, x):
        x = self.pool(self.leaky_relu(self.vdropout1(self.conv1(x))))
        x = self.pool(self.leaky_relu(self.vdropout2(self.conv2(x))))
        x = x.view(-1, 192 * 8 * 8)
        x = self.leaky_relu(self.vdropout3(self.fc1(x)))
        x = self.leaky_relu(self.vdropout4(self.fc2(x)))
        x = F.softmax(self.fc3(x), dim=1)
        return x

    def kl_prior(self, vdropout):
        c1 = 1.16145124
        c2 = -1.50204118
        c3 = 0.58629921
        return (
            -0.5 * vdropout.log_alpha
            - c1 * vdropout.alpha
            - c2 * vdropout.alpha**2
            - c3 * vdropout.alpha**3
        )

    def calc_reg(self):
        return self.reg_coef * (
            self.kl_prior(self.vdropout1)
            + self.kl_prior(self.vdropout2)
            + self.kl_prior(self.vdropout3)
            + self.kl_prior(self.vdropout4)
        )


# Lenet with MCDO
class Net_MCDO(nn.Module):
    def __init__(self):
        super(Net_MCDO, self).__init__()
        self.conv1 = nn.Conv2d(3, 192, 5, padding=2)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(192, 192, 5, padding=2)
        self.fc1 = nn.Linear(192 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 10)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.dropout = nn.Dropout(p=0.3)

        nn.init.xavier_uniform_(self.conv1.weight)
        nn.init.constant_(self.conv1.bias, 0.0)
        nn.init.xavier_uniform_(self.conv2.weight)
        nn.init.constant_(self.conv2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.constant_(self.fc1.bias, 0.0)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.constant_(self.fc2.bias, 0.0)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.constant_(self.fc3.bias, 0.0)

    def forward(self, x):
        x = self.pool(self.leaky_relu(self.dropout(self.conv1(x))))
        x = self.pool(self.leaky_relu(self.dropout(self.conv2(x))))
        x = x.view(-1, 192 * 8 * 8)
        x = self.leaky_relu(self.dropout(self.fc1(x)))
        x = self.leaky_relu(self.dropout(self.fc2(x)))
        x = F.softmax(self.fc3(x), dim=1)
        return x

# %% [markdown]
# # 4. Define a Loss function and optimizer

# %%
import torch.optim as optim

# %%
CE = nn.CrossEntropyLoss()

# %%
def train(epoch, net, optimizer, log_freq=log_freq, is_calc_reg=False):
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = CE(outputs, labels)
        if is_calc_reg:
            loss += torch.sum(net.module.calc_reg())
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if (i + 1) % log_freq == 0:  # print every 2000 mini-batches
            print(
                "[Epoch : %d, Iter: %5d] loss: %.3f"
                % (epoch + 1, i + 1, running_loss / log_freq)
            )
    return running_loss / log_freq


def test(net):
    print("Start test")
    class_correct = list(0.0 for i in range(10))
    class_total = list(0.0 for i in range(10))
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            output = 0
            for i in range(50):
                output += net(inputs) / 10.0
            output = torch.log(output)
            _, predicted = torch.max(output, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    for i in range(10):
        print(
            "Accuracy of %5s : %.2f %%"
            % (classes[i], 100 * class_correct[i] / class_total[i])
        )

    test_score = np.mean([100 * class_correct[i] / class_total[i] for i in range(10)])
    print(test_score)
    return test_score

# %%
from tqdm import tqdm_notebook

lenets = [Net_CDO, Net_VDO, Net_MCDO]
epoch_num = 300
test_freq = 10
losses = list()
net_scores = list()
test_scores = list()
cdropout_history = list()
vdropout_history = list()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
is_train = True

# SAVE
def save(name, net):
    net_path = "../saved_models/" + name + ".pkl"
    net = net.cpu()
    torch.save(net.state_dict(), net_path)
    # Place it to GPU back
    net.to(device)
    return net


def load(name, net):
    net_path = "../saved_models/" + name + ".pkl"
    # LOAD
    net.load_state_dict(torch.load(net_path))
    # Place it to GPU
    net.to(device)
    return net


def main():
    for lenet in lenets:
        print(lenet.__name__)
        net = lenet()
        if torch.cuda.device_count() > 1:
            print("Let's use", torch.cuda.device_count(), "GPUs!")
            net = nn.DataParallel(net)
        net.to(device)

        if lenet.__name__ == "Net_CDO":
            optimizer = optim.Adam(net.parameters(), lr=5e-4, amsgrad=True)
        else:
            optimizer = optim.Adam(
                net.parameters(), lr=5e-4, weight_decay=5e-4, amsgrad=True
            )
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.97)

        for i in tqdm_notebook(range(epoch_num)):
            scheduler.step()
            #             net.train()
            if lenet.__name__ == "Net_CDO":
                loss_avg = train(
                    epoch=i, net=net, optimizer=optimizer, is_calc_reg=True
                )
                cdropout_history.append(
                    (
                        net.module.cdropout1.p.item(),
                        net.module.cdropout2.p.item(),
                        net.module.cdropout3.p.item(),
                        net.module.cdropout4.p.item(),
                    )
                )
            elif lenet.__name__ == "Net_VDO":
                loss_avg = train(
                    epoch=i, net=net, optimizer=optimizer, is_calc_reg=True
                )
                vdropout_history.append(
                    (
                        net.module.vdropout1.alpha.item(),
                        net.module.vdropout2.alpha.item(),
                        net.module.vdropout3.alpha.item(),
                        net.module.vdropout4.alpha.item(),
                    )
                )
            else:
                loss_avg = train(epoch=i, net=net, optimizer=optimizer)
            losses.append(loss_avg)
            if (i + 1) % test_freq == 0:
                #                 net.eval()
                net_score = test(net)
                net_scores.append(net_score)
        save(lenet.__name__, net)

# %%
if is_train:
    main()
# Out:
# Net_CDO
# Let's use 4 GPUs!
# /tmp/ipykernel_258958/2558541425.py:50: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(epoch_num)):
#   0%|          | 0/300 [00:00<?, ?it/s]
# [Epoch : 1, Iter:    50] loss: 2.976
# [Epoch : 2, Iter:    50] loss: 2.367
# [Epoch : 3, Iter:    50] loss: 2.209
# [Epoch : 4, Iter:    50] loss: 2.139
# [Epoch : 5, Iter:    50] loss: 2.096
# [Epoch : 6, Iter:    50] loss: 2.053
# [Epoch : 7, Iter:    50] loss: 2.022
# [Epoch : 8, Iter:    50] loss: 2.004
# [Epoch : 9, Iter:    50] loss: 1.982
# [Epoch : 10, Iter:    50] loss: 1.960
# Start test
# Accuracy of plane : 77.40 %
# Accuracy of   car : 83.00 %
# Accuracy of  bird : 42.70 %
# Accuracy of   cat : 28.80 %
# Accuracy of  deer : 26.00 %
# Accuracy of   dog : 69.80 %
# Accuracy of  frog : 84.20 %
# Accuracy of horse : 65.20 %
# Accuracy of  ship : 76.30 %
# Accuracy of truck : 75.50 %
# 62.89
# [Epoch : 11, Iter:    50] loss: 1.949
# [Epoch : 12, Iter:    50] loss: 1.936
# [Epoch : 13, Iter:    50] loss: 1.930
# [Epoch : 14, Iter:    50] loss: 1.920
# [Epoch : 15, Iter:    50] loss: 1.906
# [Epoch : 16, Iter:    50] loss: 1.897
# [Epoch : 17, Iter:    50] loss: 1.891
# [Epoch : 18, Iter:    50] loss: 1.885
# [Epoch : 19, Iter:    50] loss: 1.885
# [Epoch : 20, Iter:    50] loss: 1.873
# Start test
# Accuracy of plane : 83.70 %
# Accuracy of   car : 88.10 %
# Accuracy of  bird : 58.30 %
# Accuracy of   cat : 41.70 %
# Accuracy of  deer : 61.70 %
# Accuracy of   dog : 66.10 %
# Accuracy of  frog : 84.40 %
# Accuracy of horse : 78.20 %
# Accuracy of  ship : 77.40 %
# Accuracy of truck : 82.70 %
# 72.23
# [Epoch : 21, Iter:    50] loss: 1.869
# [Epoch : 22, Iter:    50] loss: 1.865
# [Epoch : 23, Iter:    50] loss: 1.858
# [Epoch : 24, Iter:    50] loss: 1.853
# [Epoch : 25, Iter:    50] loss: 1.850
# [Epoch : 26, Iter:    50] loss: 1.849
# [Epoch : 27, Iter:    50] loss: 1.848
# [Epoch : 28, Iter:    50] loss: 1.838
# [Epoch : 29, Iter:    50] loss: 1.838
# [Epoch : 30, Iter:    50] loss: 1.840
# Start test
# Accuracy of plane : 86.30 %
# Accuracy of   car : 90.20 %
# Accuracy of  bird : 66.50 %
# Accuracy of   cat : 40.00 %
# Accuracy of  deer : 66.70 %
# Accuracy of   dog : 57.70 %
# Accuracy of  frog : 87.80 %
# Accuracy of horse : 83.30 %
# Accuracy of  ship : 79.90 %
# Accuracy of truck : 79.50 %
# 73.78999999999999
# [Epoch : 31, Iter:    50] loss: 1.835
# [Epoch : 32, Iter:    50] loss: 1.829
# [Epoch : 33, Iter:    50] loss: 1.827
# [Epoch : 34, Iter:    50] loss: 1.825
# [Epoch : 35, Iter:    50] loss: 1.821
# [Epoch : 36, Iter:    50] loss: 1.825
# [Epoch : 37, Iter:    50] loss: 1.819
# [Epoch : 38, Iter:    50] loss: 1.813
# [Epoch : 39, Iter:    50] loss: 1.812
# [Epoch : 40, Iter:    50] loss: 1.807
# Start test
# Accuracy of plane : 80.10 %
# Accuracy of   car : 85.60 %
# Accuracy of  bird : 66.40 %
# Accuracy of   cat : 54.80 %
# Accuracy of  deer : 67.70 %
# Accuracy of   dog : 72.20 %
# Accuracy of  frog : 83.90 %
# Accuracy of horse : 84.50 %
# Accuracy of  ship : 88.40 %
# Accuracy of truck : 87.70 %
# 77.13000000000001
# [Epoch : 41, Iter:    50] loss: 1.807
# [Epoch : 42, Iter:    50] loss: 1.805
# [Epoch : 43, Iter:    50] loss: 1.807
# [Epoch : 44, Iter:    50] loss: 1.800
# [Epoch : 45, Iter:    50] loss: 1.801
# [Epoch : 46, Iter:    50] loss: 1.798
# [Epoch : 47, Iter:    50] loss: 1.800
# [Epoch : 48, Iter:    50] loss: 1.795
# [Epoch : 49, Iter:    50] loss: 1.790
# [Epoch : 50, Iter:    50] loss: 1.791
# Start test
# Accuracy of plane : 83.40 %
# Accuracy of   car : 88.50 %
# Accuracy of  bird : 60.80 %
# Accuracy of   cat : 63.40 %
# Accuracy of  deer : 78.50 %
# Accuracy of   dog : 71.50 %
# Accuracy of  frog : 84.20 %
# Accuracy of horse : 83.30 %
# Accuracy of  ship : 84.00 %
# Accuracy of truck : 85.90 %
# 78.35
# [Epoch : 51, Iter:    50] loss: 1.790
# [Epoch : 52, Iter:    50] loss: 1.790
# [Epoch : 53, Iter:    50] loss: 1.783
# [Epoch : 54, Iter:    50] loss: 1.782
# [Epoch : 55, Iter:    50] loss: 1.785
# [Epoch : 56, Iter:    50] loss: 1.781
# [Epoch : 57, Iter:    50] loss: 1.779
# [Epoch : 58, Iter:    50] loss: 1.784
# [Epoch : 59, Iter:    50] loss: 1.781
# [Epoch : 60, Iter:    50] loss: 1.776
# Start test
# Accuracy of plane : 80.90 %
# Accuracy of   car : 85.10 %
# Accuracy of  bird : 61.80 %
# Accuracy of   cat : 60.80 %
# Accuracy of  deer : 69.30 %
# Accuracy of   dog : 78.10 %
# Accuracy of  frog : 85.70 %
# Accuracy of horse : 84.00 %
# Accuracy of  ship : 86.60 %
# Accuracy of truck : 88.70 %
# 78.10000000000001
# [Epoch : 61, Iter:    50] loss: 1.778
# [Epoch : 62, Iter:    50] loss: 1.773
# [Epoch : 63, Iter:    50] loss: 1.775
# [Epoch : 64, Iter:    50] loss: 1.775
# [Epoch : 65, Iter:    50] loss: 1.769
# [Epoch : 66, Iter:    50] loss: 1.773
# [Epoch : 67, Iter:    50] loss: 1.767
# [Epoch : 68, Iter:    50] loss: 1.765
# [Epoch : 69, Iter:    50] loss: 1.765
# [Epoch : 70, Iter:    50] loss: 1.764
# Start test
# Accuracy of plane : 80.60 %
# Accuracy of   car : 88.30 %
# Accuracy of  bird : 65.30 %
# Accuracy of   cat : 52.00 %
# Accuracy of  deer : 75.00 %
# Accuracy of   dog : 76.00 %
# Accuracy of  frog : 88.10 %
# Accuracy of horse : 87.90 %
# Accuracy of  ship : 88.20 %
# Accuracy of truck : 90.80 %
# 79.22
# [Epoch : 71, Iter:    50] loss: 1.766
# [Epoch : 72, Iter:    50] loss: 1.761
# [Epoch : 73, Iter:    50] loss: 1.763
# [Epoch : 74, Iter:    50] loss: 1.759
# [Epoch : 75, Iter:    50] loss: 1.763
# [Epoch : 76, Iter:    50] loss: 1.760
# [Epoch : 77, Iter:    50] loss: 1.761
# [Epoch : 78, Iter:    50] loss: 1.758
# [Epoch : 79, Iter:    50] loss: 1.758
# [Epoch : 80, Iter:    50] loss: 1.755
# Start test
# Accuracy of plane : 80.10 %
# Accuracy of   car : 93.70 %
# Accuracy of  bird : 74.30 %
# Accuracy of   cat : 65.10 %
# Accuracy of  deer : 82.60 %
# Accuracy of   dog : 68.30 %
# Accuracy of  frog : 86.20 %
# Accuracy of horse : 82.80 %
# Accuracy of  ship : 88.50 %
# Accuracy of truck : 82.70 %
# 80.42999999999999
# [Epoch : 81, Iter:    50] loss: 1.757
# [Epoch : 82, Iter:    50] loss: 1.753
# [Epoch : 83, Iter:    50] loss: 1.753
# [Epoch : 84, Iter:    50] loss: 1.755
# [Epoch : 85, Iter:    50] loss: 1.752
# [Epoch : 86, Iter:    50] loss: 1.752
# [Epoch : 87, Iter:    50] loss: 1.750
# [Epoch : 88, Iter:    50] loss: 1.747
# [Epoch : 89, Iter:    50] loss: 1.748
# [Epoch : 90, Iter:    50] loss: 1.747
# Start test
# Accuracy of plane : 76.10 %
# Accuracy of   car : 91.20 %
# Accuracy of  bird : 70.00 %
# Accuracy of   cat : 70.90 %
# Accuracy of  deer : 69.90 %
# Accuracy of   dog : 69.10 %
# Accuracy of  frog : 90.10 %
# Accuracy of horse : 82.70 %
# Accuracy of  ship : 93.70 %
# Accuracy of truck : 88.90 %
# 80.26
# [Epoch : 91, Iter:    50] loss: 1.748
# [Epoch : 92, Iter:    50] loss: 1.744
# [Epoch : 93, Iter:    50] loss: 1.742
# [Epoch : 94, Iter:    50] loss: 1.743
# [Epoch : 95, Iter:    50] loss: 1.745
# [Epoch : 96, Iter:    50] loss: 1.743
# [Epoch : 97, Iter:    50] loss: 1.741
# [Epoch : 98, Iter:    50] loss: 1.741
# [Epoch : 99, Iter:    50] loss: 1.740
# [Epoch : 100, Iter:    50] loss: 1.738
# Start test
# Accuracy of plane : 84.30 %
# Accuracy of   car : 92.60 %
# Accuracy of  bird : 75.50 %
# Accuracy of   cat : 50.00 %
# Accuracy of  deer : 69.20 %
# Accuracy of   dog : 78.20 %
# Accuracy of  frog : 87.90 %
# Accuracy of horse : 88.50 %
# Accuracy of  ship : 87.40 %
# Accuracy of truck : 88.80 %
# 80.24
# [Epoch : 101, Iter:    50] loss: 1.738
# [Epoch : 102, Iter:    50] loss: 1.737
# [Epoch : 103, Iter:    50] loss: 1.738
# [Epoch : 104, Iter:    50] loss: 1.736
# [Epoch : 105, Iter:    50] loss: 1.737
# [Epoch : 106, Iter:    50] loss: 1.734
# [Epoch : 107, Iter:    50] loss: 1.733
# [Epoch : 108, Iter:    50] loss: 1.734
# [Epoch : 109, Iter:    50] loss: 1.735
# [Epoch : 110, Iter:    50] loss: 1.734
# Start test
# Accuracy of plane : 82.70 %
# Accuracy of   car : 89.30 %
# Accuracy of  bird : 66.30 %
# Accuracy of   cat : 66.90 %
# Accuracy of  deer : 80.50 %
# Accuracy of   dog : 74.20 %
# Accuracy of  frog : 89.40 %
# Accuracy of horse : 83.40 %
# Accuracy of  ship : 91.80 %
# Accuracy of truck : 89.80 %
# 81.42999999999999
# [Epoch : 111, Iter:    50] loss: 1.732
# [Epoch : 112, Iter:    50] loss: 1.732
# [Epoch : 113, Iter:    50] loss: 1.734
# [Epoch : 114, Iter:    50] loss: 1.732
# [Epoch : 115, Iter:    50] loss: 1.730
# [Epoch : 116, Iter:    50] loss: 1.729
# [Epoch : 117, Iter:    50] loss: 1.730
# [Epoch : 118, Iter:    50] loss: 1.729
# [Epoch : 119, Iter:    50] loss: 1.727
# [Epoch : 120, Iter:    50] loss: 1.731
# Start test
# Accuracy of plane : 83.00 %
# Accuracy of   car : 90.50 %
# Accuracy of  bird : 66.60 %
# Accuracy of   cat : 63.90 %
# Accuracy of  deer : 74.70 %
# Accuracy of   dog : 77.90 %
# Accuracy of  frog : 88.40 %
# Accuracy of horse : 88.20 %
# Accuracy of  ship : 91.60 %
# Accuracy of truck : 90.50 %
# 81.53
# [Epoch : 121, Iter:    50] loss: 1.728
# [Epoch : 122, Iter:    50] loss: 1.726
# [Epoch : 123, Iter:    50] loss: 1.728
# [Epoch : 124, Iter:    50] loss: 1.726
# [Epoch : 125, Iter:    50] loss: 1.725
# [Epoch : 126, Iter:    50] loss: 1.725
# [Epoch : 127, Iter:    50] loss: 1.724
# [Epoch : 128, Iter:    50] loss: 1.727
# [Epoch : 129, Iter:    50] loss: 1.724
# [Epoch : 130, Iter:    50] loss: 1.723
# Start test
# Accuracy of plane : 89.10 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 69.70 %
# Accuracy of   cat : 58.70 %
# Accuracy of  deer : 84.60 %
# Accuracy of   dog : 73.40 %
# Accuracy of  frog : 88.90 %
# Accuracy of horse : 90.90 %
# Accuracy of  ship : 86.00 %
# Accuracy of truck : 89.40 %
# 82.38000000000001
# [Epoch : 131, Iter:    50] loss: 1.722
# [Epoch : 132, Iter:    50] loss: 1.723
# [Epoch : 133, Iter:    50] loss: 1.723
# [Epoch : 134, Iter:    50] loss: 1.719
# [Epoch : 135, Iter:    50] loss: 1.719
# [Epoch : 136, Iter:    50] loss: 1.719
# [Epoch : 137, Iter:    50] loss: 1.721
# [Epoch : 138, Iter:    50] loss: 1.720
# [Epoch : 139, Iter:    50] loss: 1.720
# [Epoch : 140, Iter:    50] loss: 1.720
# Start test
# Accuracy of plane : 85.60 %
# Accuracy of   car : 88.50 %
# Accuracy of  bird : 73.80 %
# Accuracy of   cat : 59.40 %
# Accuracy of  deer : 83.50 %
# Accuracy of   dog : 76.30 %
# Accuracy of  frog : 89.60 %
# Accuracy of horse : 85.40 %
# Accuracy of  ship : 90.30 %
# Accuracy of truck : 90.60 %
# 82.29999999999998
# [Epoch : 141, Iter:    50] loss: 1.718
# [Epoch : 142, Iter:    50] loss: 1.718
# [Epoch : 143, Iter:    50] loss: 1.717
# [Epoch : 144, Iter:    50] loss: 1.717
# [Epoch : 145, Iter:    50] loss: 1.717
# [Epoch : 146, Iter:    50] loss: 1.715
# [Epoch : 147, Iter:    50] loss: 1.716
# [Epoch : 148, Iter:    50] loss: 1.717
# [Epoch : 149, Iter:    50] loss: 1.715
# [Epoch : 150, Iter:    50] loss: 1.713
# Start test
# Accuracy of plane : 88.10 %
# Accuracy of   car : 89.90 %
# Accuracy of  bird : 72.30 %
# Accuracy of   cat : 66.90 %
# Accuracy of  deer : 79.50 %
# Accuracy of   dog : 73.20 %
# Accuracy of  frog : 89.30 %
# Accuracy of horse : 88.80 %
# Accuracy of  ship : 87.50 %
# Accuracy of truck : 91.90 %
# 82.74
# [Epoch : 151, Iter:    50] loss: 1.715
# [Epoch : 152, Iter:    50] loss: 1.715
# [Epoch : 153, Iter:    50] loss: 1.713
# [Epoch : 154, Iter:    50] loss: 1.714
# [Epoch : 155, Iter:    50] loss: 1.713
# [Epoch : 156, Iter:    50] loss: 1.712
# [Epoch : 157, Iter:    50] loss: 1.713
# [Epoch : 158, Iter:    50] loss: 1.712
# [Epoch : 159, Iter:    50] loss: 1.713
# [Epoch : 160, Iter:    50] loss: 1.713
# Start test
# Accuracy of plane : 89.20 %
# Accuracy of   car : 90.40 %
# Accuracy of  bird : 76.30 %
# Accuracy of   cat : 65.20 %
# Accuracy of  deer : 80.50 %
# Accuracy of   dog : 75.20 %
# Accuracy of  frog : 88.10 %
# Accuracy of horse : 84.40 %
# Accuracy of  ship : 88.20 %
# Accuracy of truck : 90.40 %
# 82.78999999999999
# [Epoch : 161, Iter:    50] loss: 1.712
# [Epoch : 162, Iter:    50] loss: 1.712
# [Epoch : 163, Iter:    50] loss: 1.713
# [Epoch : 164, Iter:    50] loss: 1.710
# [Epoch : 165, Iter:    50] loss: 1.711
# [Epoch : 166, Iter:    50] loss: 1.710
# [Epoch : 167, Iter:    50] loss: 1.709
# [Epoch : 168, Iter:    50] loss: 1.709
# [Epoch : 169, Iter:    50] loss: 1.709
# [Epoch : 170, Iter:    50] loss: 1.708
# Start test
# Accuracy of plane : 90.20 %
# Accuracy of   car : 92.20 %
# Accuracy of  bird : 74.00 %
# Accuracy of   cat : 60.40 %
# Accuracy of  deer : 85.70 %
# Accuracy of   dog : 76.60 %
# Accuracy of  frog : 87.40 %
# Accuracy of horse : 85.80 %
# Accuracy of  ship : 90.50 %
# Accuracy of truck : 87.70 %
# 83.05
# [Epoch : 171, Iter:    50] loss: 1.708
# [Epoch : 172, Iter:    50] loss: 1.710
# [Epoch : 173, Iter:    50] loss: 1.708
# [Epoch : 174, Iter:    50] loss: 1.709
# [Epoch : 175, Iter:    50] loss: 1.708
# [Epoch : 176, Iter:    50] loss: 1.708
# [Epoch : 177, Iter:    50] loss: 1.707
# [Epoch : 178, Iter:    50] loss: 1.707
# [Epoch : 179, Iter:    50] loss: 1.707
# [Epoch : 180, Iter:    50] loss: 1.707
# Start test
# Accuracy of plane : 89.70 %
# Accuracy of   car : 92.50 %
# Accuracy of  bird : 77.20 %
# Accuracy of   cat : 62.80 %
# Accuracy of  deer : 81.00 %
# Accuracy of   dog : 74.40 %
# Accuracy of  frog : 90.00 %
# Accuracy of horse : 89.20 %
# Accuracy of  ship : 88.50 %
# Accuracy of truck : 89.20 %
# 83.45
# [Epoch : 181, Iter:    50] loss: 1.706
# [Epoch : 182, Iter:    50] loss: 1.706
# [Epoch : 183, Iter:    50] loss: 1.706
# [Epoch : 184, Iter:    50] loss: 1.705
# [Epoch : 185, Iter:    50] loss: 1.704
# [Epoch : 186, Iter:    50] loss: 1.705
# [Epoch : 187, Iter:    50] loss: 1.706
# [Epoch : 188, Iter:    50] loss: 1.706
# [Epoch : 189, Iter:    50] loss: 1.704
# [Epoch : 190, Iter:    50] loss: 1.705
# Start test
# Accuracy of plane : 84.70 %
# Accuracy of   car : 91.20 %
# Accuracy of  bird : 74.30 %
# Accuracy of   cat : 64.50 %
# Accuracy of  deer : 83.50 %
# Accuracy of   dog : 73.20 %
# Accuracy of  frog : 91.60 %
# Accuracy of horse : 88.50 %
# Accuracy of  ship : 92.50 %
# Accuracy of truck : 89.70 %
# 83.37
# [Epoch : 191, Iter:    50] loss: 1.706
# [Epoch : 192, Iter:    50] loss: 1.705
# [Epoch : 193, Iter:    50] loss: 1.704
# [Epoch : 194, Iter:    50] loss: 1.702
# [Epoch : 195, Iter:    50] loss: 1.704
# [Epoch : 196, Iter:    50] loss: 1.704
# [Epoch : 197, Iter:    50] loss: 1.702
# [Epoch : 198, Iter:    50] loss: 1.703
# [Epoch : 199, Iter:    50] loss: 1.704
# [Epoch : 200, Iter:    50] loss: 1.704
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 93.70 %
# Accuracy of  bird : 77.10 %
# Accuracy of   cat : 62.50 %
# Accuracy of  deer : 83.10 %
# Accuracy of   dog : 74.40 %
# Accuracy of  frog : 90.60 %
# Accuracy of horse : 88.20 %
# Accuracy of  ship : 90.40 %
# Accuracy of truck : 88.50 %
# 83.58000000000001
# [Epoch : 201, Iter:    50] loss: 1.701
# [Epoch : 202, Iter:    50] loss: 1.702
# [Epoch : 203, Iter:    50] loss: 1.700
# [Epoch : 204, Iter:    50] loss: 1.702
# [Epoch : 205, Iter:    50] loss: 1.701
# [Epoch : 206, Iter:    50] loss: 1.702
# [Epoch : 207, Iter:    50] loss: 1.701
# [Epoch : 208, Iter:    50] loss: 1.702
# [Epoch : 209, Iter:    50] loss: 1.700
# [Epoch : 210, Iter:    50] loss: 1.700
# Start test
# Accuracy of plane : 86.60 %
# Accuracy of   car : 91.90 %
# Accuracy of  bird : 74.80 %
# Accuracy of   cat : 69.00 %
# Accuracy of  deer : 85.60 %
# Accuracy of   dog : 73.10 %
# Accuracy of  frog : 87.70 %
# Accuracy of horse : 87.60 %
# Accuracy of  ship : 91.50 %
# Accuracy of truck : 87.90 %
# 83.57
# [Epoch : 211, Iter:    50] loss: 1.699
# [Epoch : 212, Iter:    50] loss: 1.700
# [Epoch : 213, Iter:    50] loss: 1.700
# [Epoch : 214, Iter:    50] loss: 1.699
# [Epoch : 215, Iter:    50] loss: 1.700
# [Epoch : 216, Iter:    50] loss: 1.700
# [Epoch : 217, Iter:    50] loss: 1.700
# [Epoch : 218, Iter:    50] loss: 1.699
# [Epoch : 219, Iter:    50] loss: 1.700
# [Epoch : 220, Iter:    50] loss: 1.699
# Start test
# Accuracy of plane : 87.10 %
# Accuracy of   car : 91.30 %
# Accuracy of  bird : 74.80 %
# Accuracy of   cat : 66.40 %
# Accuracy of  deer : 83.20 %
# Accuracy of   dog : 75.90 %
# Accuracy of  frog : 89.30 %
# Accuracy of horse : 88.50 %
# Accuracy of  ship : 91.50 %
# Accuracy of truck : 90.00 %
# 83.8
# [Epoch : 221, Iter:    50] loss: 1.698
# [Epoch : 222, Iter:    50] loss: 1.698
# [Epoch : 223, Iter:    50] loss: 1.699
# [Epoch : 224, Iter:    50] loss: 1.698
# [Epoch : 225, Iter:    50] loss: 1.697
# [Epoch : 226, Iter:    50] loss: 1.697
# [Epoch : 227, Iter:    50] loss: 1.698
# [Epoch : 228, Iter:    50] loss: 1.698
# [Epoch : 229, Iter:    50] loss: 1.697
# [Epoch : 230, Iter:    50] loss: 1.698
# Start test
# Accuracy of plane : 88.40 %
# Accuracy of   car : 92.00 %
# Accuracy of  bird : 76.10 %
# Accuracy of   cat : 65.10 %
# Accuracy of  deer : 84.70 %
# Accuracy of   dog : 75.40 %
# Accuracy of  frog : 87.90 %
# Accuracy of horse : 87.00 %
# Accuracy of  ship : 91.20 %
# Accuracy of truck : 88.10 %
# 83.59
# [Epoch : 231, Iter:    50] loss: 1.697
# [Epoch : 232, Iter:    50] loss: 1.698
# [Epoch : 233, Iter:    50] loss: 1.697
# [Epoch : 234, Iter:    50] loss: 1.697
# [Epoch : 235, Iter:    50] loss: 1.697
# [Epoch : 236, Iter:    50] loss: 1.696
# [Epoch : 237, Iter:    50] loss: 1.698
# [Epoch : 238, Iter:    50] loss: 1.698
# [Epoch : 239, Iter:    50] loss: 1.696
# [Epoch : 240, Iter:    50] loss: 1.697
# Start test
# Accuracy of plane : 86.10 %
# Accuracy of   car : 91.50 %
# Accuracy of  bird : 73.70 %
# Accuracy of   cat : 66.80 %
# Accuracy of  deer : 83.50 %
# Accuracy of   dog : 77.50 %
# Accuracy of  frog : 88.80 %
# Accuracy of horse : 87.40 %
# Accuracy of  ship : 92.20 %
# Accuracy of truck : 89.60 %
# 83.71000000000001
# [Epoch : 241, Iter:    50] loss: 1.695
# [Epoch : 242, Iter:    50] loss: 1.696
# [Epoch : 243, Iter:    50] loss: 1.695
# [Epoch : 244, Iter:    50] loss: 1.696
# [Epoch : 245, Iter:    50] loss: 1.696
# [Epoch : 246, Iter:    50] loss: 1.697
# [Epoch : 247, Iter:    50] loss: 1.696
# [Epoch : 248, Iter:    50] loss: 1.696
# [Epoch : 249, Iter:    50] loss: 1.696
# [Epoch : 250, Iter:    50] loss: 1.695
# Start test
# Accuracy of plane : 86.40 %
# Accuracy of   car : 92.70 %
# Accuracy of  bird : 75.00 %
# Accuracy of   cat : 66.80 %
# Accuracy of  deer : 84.50 %
# Accuracy of   dog : 74.20 %
# Accuracy of  frog : 90.10 %
# Accuracy of horse : 87.70 %
# Accuracy of  ship : 91.90 %
# Accuracy of truck : 89.30 %
# 83.86
# [Epoch : 251, Iter:    50] loss: 1.697
# [Epoch : 252, Iter:    50] loss: 1.695
# [Epoch : 253, Iter:    50] loss: 1.695
# [Epoch : 254, Iter:    50] loss: 1.697
# [Epoch : 255, Iter:    50] loss: 1.695
# [Epoch : 256, Iter:    50] loss: 1.697
# [Epoch : 257, Iter:    50] loss: 1.695
# [Epoch : 258, Iter:    50] loss: 1.696
# [Epoch : 259, Iter:    50] loss: 1.695
# [Epoch : 260, Iter:    50] loss: 1.694
# Start test
# Accuracy of plane : 88.00 %
# Accuracy of   car : 92.20 %
# Accuracy of  bird : 77.90 %
# Accuracy of   cat : 64.60 %
# Accuracy of  deer : 85.30 %
# Accuracy of   dog : 75.60 %
# Accuracy of  frog : 89.10 %
# Accuracy of horse : 86.20 %
# Accuracy of  ship : 91.20 %
# Accuracy of truck : 88.10 %
# 83.82000000000001
# [Epoch : 261, Iter:    50] loss: 1.695
# [Epoch : 262, Iter:    50] loss: 1.695
# [Epoch : 263, Iter:    50] loss: 1.693
# [Epoch : 264, Iter:    50] loss: 1.695
# [Epoch : 265, Iter:    50] loss: 1.695
# [Epoch : 266, Iter:    50] loss: 1.695
# [Epoch : 267, Iter:    50] loss: 1.694
# [Epoch : 268, Iter:    50] loss: 1.693
# [Epoch : 269, Iter:    50] loss: 1.694
# [Epoch : 270, Iter:    50] loss: 1.694
# Start test
# Accuracy of plane : 86.70 %
# Accuracy of   car : 91.80 %
# Accuracy of  bird : 76.10 %
# Accuracy of   cat : 66.70 %
# Accuracy of  deer : 83.30 %
# Accuracy of   dog : 75.80 %
# Accuracy of  frog : 90.10 %
# Accuracy of horse : 87.20 %
# Accuracy of  ship : 91.10 %
# Accuracy of truck : 90.90 %
# 83.97
# [Epoch : 271, Iter:    50] loss: 1.694
# [Epoch : 272, Iter:    50] loss: 1.694
# [Epoch : 273, Iter:    50] loss: 1.693
# [Epoch : 274, Iter:    50] loss: 1.695
# [Epoch : 275, Iter:    50] loss: 1.694
# [Epoch : 276, Iter:    50] loss: 1.694
# [Epoch : 277, Iter:    50] loss: 1.694
# [Epoch : 278, Iter:    50] loss: 1.694
# [Epoch : 279, Iter:    50] loss: 1.694
# [Epoch : 280, Iter:    50] loss: 1.692
# Start test
# Accuracy of plane : 86.70 %
# Accuracy of   car : 91.80 %
# Accuracy of  bird : 77.20 %
# Accuracy of   cat : 69.20 %
# Accuracy of  deer : 83.70 %
# Accuracy of   dog : 74.50 %
# Accuracy of  frog : 88.80 %
# Accuracy of horse : 87.70 %
# Accuracy of  ship : 91.90 %
# Accuracy of truck : 88.70 %
# 84.02
# [Epoch : 281, Iter:    50] loss: 1.693
# [Epoch : 282, Iter:    50] loss: 1.693
# [Epoch : 283, Iter:    50] loss: 1.694
# [Epoch : 284, Iter:    50] loss: 1.694
# [Epoch : 285, Iter:    50] loss: 1.693
# [Epoch : 286, Iter:    50] loss: 1.692
# [Epoch : 287, Iter:    50] loss: 1.694
# [Epoch : 288, Iter:    50] loss: 1.695
# [Epoch : 289, Iter:    50] loss: 1.692
# [Epoch : 290, Iter:    50] loss: 1.693
# Start test
# Accuracy of plane : 86.70 %
# Accuracy of   car : 92.80 %
# Accuracy of  bird : 73.80 %
# Accuracy of   cat : 67.90 %
# Accuracy of  deer : 84.30 %
# Accuracy of   dog : 75.30 %
# Accuracy of  frog : 90.80 %
# Accuracy of horse : 87.10 %
# Accuracy of  ship : 91.50 %
# Accuracy of truck : 88.80 %
# 83.9
# [Epoch : 291, Iter:    50] loss: 1.693
# [Epoch : 292, Iter:    50] loss: 1.694
# [Epoch : 293, Iter:    50] loss: 1.692
# [Epoch : 294, Iter:    50] loss: 1.692
# [Epoch : 295, Iter:    50] loss: 1.692
# [Epoch : 296, Iter:    50] loss: 1.692
# [Epoch : 297, Iter:    50] loss: 1.693
# [Epoch : 298, Iter:    50] loss: 1.692
# [Epoch : 299, Iter:    50] loss: 1.692
# [Epoch : 300, Iter:    50] loss: 1.692
# Start test
# Accuracy of plane : 87.00 %
# Accuracy of   car : 92.70 %
# Accuracy of  bird : 74.80 %
# Accuracy of   cat : 67.80 %
# Accuracy of  deer : 83.80 %
# Accuracy of   dog : 74.90 %
# Accuracy of  frog : 89.30 %
# Accuracy of horse : 88.90 %
# Accuracy of  ship : 91.50 %
# Accuracy of truck : 89.00 %
# 83.97
# Net_VDO
# Let's use 4 GPUs!
#   0%|          | 0/300 [00:00<?, ?it/s]
# [Epoch : 1, Iter:    50] loss: 2.166
# [Epoch : 2, Iter:    50] loss: 2.054
# [Epoch : 3, Iter:    50] loss: 2.004
# [Epoch : 4, Iter:    50] loss: 1.966
# [Epoch : 5, Iter:    50] loss: 1.934
# [Epoch : 6, Iter:    50] loss: 1.906
# [Epoch : 7, Iter:    50] loss: 1.885
# [Epoch : 8, Iter:    50] loss: 1.863
# [Epoch : 9, Iter:    50] loss: 1.850
# [Epoch : 10, Iter:    50] loss: 1.838
# Start test
# Accuracy of plane : 77.80 %
# Accuracy of   car : 92.00 %
# Accuracy of  bird : 44.40 %
# Accuracy of   cat : 38.30 %
# Accuracy of  deer : 40.50 %
# Accuracy of   dog : 75.00 %
# Accuracy of  frog : 66.20 %
# Accuracy of horse : 74.60 %
# Accuracy of  ship : 70.20 %
# Accuracy of truck : 62.90 %
# 64.19
# [Epoch : 11, Iter:    50] loss: 1.827
# [Epoch : 12, Iter:    50] loss: 1.820
# [Epoch : 13, Iter:    50] loss: 1.809
# [Epoch : 14, Iter:    50] loss: 1.800
# [Epoch : 15, Iter:    50] loss: 1.793
# [Epoch : 16, Iter:    50] loss: 1.788
# [Epoch : 17, Iter:    50] loss: 1.780
# [Epoch : 18, Iter:    50] loss: 1.778
# [Epoch : 19, Iter:    50] loss: 1.772
# [Epoch : 20, Iter:    50] loss: 1.769
# Start test
# Accuracy of plane : 75.90 %
# Accuracy of   car : 80.10 %
# Accuracy of  bird : 56.50 %
# Accuracy of   cat : 56.60 %
# Accuracy of  deer : 56.30 %
# Accuracy of   dog : 67.50 %
# Accuracy of  frog : 80.90 %
# Accuracy of horse : 74.30 %
# Accuracy of  ship : 85.10 %
# Accuracy of truck : 85.30 %
# 71.85
# [Epoch : 21, Iter:    50] loss: 1.760
# [Epoch : 22, Iter:    50] loss: 1.758
# [Epoch : 23, Iter:    50] loss: 1.752
# [Epoch : 24, Iter:    50] loss: 1.748
# [Epoch : 25, Iter:    50] loss: 1.744
# [Epoch : 26, Iter:    50] loss: 1.737
# [Epoch : 27, Iter:    50] loss: 1.734
# [Epoch : 28, Iter:    50] loss: 1.737
# [Epoch : 29, Iter:    50] loss: 1.732
# [Epoch : 30, Iter:    50] loss: 1.734
# Start test
# Accuracy of plane : 78.50 %
# Accuracy of   car : 83.70 %
# Accuracy of  bird : 65.30 %
# Accuracy of   cat : 44.00 %
# Accuracy of  deer : 67.80 %
# Accuracy of   dog : 80.40 %
# Accuracy of  frog : 85.60 %
# Accuracy of horse : 78.10 %
# Accuracy of  ship : 86.90 %
# Accuracy of truck : 81.40 %
# 75.16999999999999
# [Epoch : 31, Iter:    50] loss: 1.728
# [Epoch : 32, Iter:    50] loss: 1.723
# [Epoch : 33, Iter:    50] loss: 1.720
# [Epoch : 34, Iter:    50] loss: 1.719
# [Epoch : 35, Iter:    50] loss: 1.717
# [Epoch : 36, Iter:    50] loss: 1.712
# [Epoch : 37, Iter:    50] loss: 1.709
# [Epoch : 38, Iter:    50] loss: 1.709
# [Epoch : 39, Iter:    50] loss: 1.703
# [Epoch : 40, Iter:    50] loss: 1.701
# Start test
# Accuracy of plane : 82.70 %
# Accuracy of   car : 93.40 %
# Accuracy of  bird : 67.30 %
# Accuracy of   cat : 60.40 %
# Accuracy of  deer : 80.10 %
# Accuracy of   dog : 67.30 %
# Accuracy of  frog : 80.80 %
# Accuracy of horse : 84.00 %
# Accuracy of  ship : 88.20 %
# Accuracy of truck : 81.00 %
# 78.52000000000001
# [Epoch : 41, Iter:    50] loss: 1.703
# [Epoch : 42, Iter:    50] loss: 1.703
# [Epoch : 43, Iter:    50] loss: 1.698
# [Epoch : 44, Iter:    50] loss: 1.696
# [Epoch : 45, Iter:    50] loss: 1.700
# [Epoch : 46, Iter:    50] loss: 1.696
# [Epoch : 47, Iter:    50] loss: 1.691
# [Epoch : 48, Iter:    50] loss: 1.688
# [Epoch : 49, Iter:    50] loss: 1.685
# [Epoch : 50, Iter:    50] loss: 1.686
# Start test
# Accuracy of plane : 86.20 %
# Accuracy of   car : 88.30 %
# Accuracy of  bird : 62.50 %
# Accuracy of   cat : 54.00 %
# Accuracy of  deer : 78.00 %
# Accuracy of   dog : 73.70 %
# Accuracy of  frog : 90.20 %
# Accuracy of horse : 81.30 %
# Accuracy of  ship : 89.80 %
# Accuracy of truck : 82.90 %
# 78.69
# [Epoch : 51, Iter:    50] loss: 1.688
# [Epoch : 52, Iter:    50] loss: 1.682
# [Epoch : 53, Iter:    50] loss: 1.682
# [Epoch : 54, Iter:    50] loss: 1.679
# [Epoch : 55, Iter:    50] loss: 1.679
# [Epoch : 56, Iter:    50] loss: 1.683
# [Epoch : 57, Iter:    50] loss: 1.676
# [Epoch : 58, Iter:    50] loss: 1.673
# [Epoch : 59, Iter:    50] loss: 1.675
# [Epoch : 60, Iter:    50] loss: 1.673
# Start test
# Accuracy of plane : 85.90 %
# Accuracy of   car : 91.30 %
# Accuracy of  bird : 65.50 %
# Accuracy of   cat : 50.90 %
# Accuracy of  deer : 79.30 %
# Accuracy of   dog : 80.10 %
# Accuracy of  frog : 83.10 %
# Accuracy of horse : 87.60 %
# Accuracy of  ship : 84.80 %
# Accuracy of truck : 90.00 %
# 79.85
# [Epoch : 61, Iter:    50] loss: 1.670
# [Epoch : 62, Iter:    50] loss: 1.670
# [Epoch : 63, Iter:    50] loss: 1.669
# [Epoch : 64, Iter:    50] loss: 1.666
# [Epoch : 65, Iter:    50] loss: 1.666
# [Epoch : 66, Iter:    50] loss: 1.662
# [Epoch : 67, Iter:    50] loss: 1.662
# [Epoch : 68, Iter:    50] loss: 1.661
# [Epoch : 69, Iter:    50] loss: 1.658
# [Epoch : 70, Iter:    50] loss: 1.656
# Start test
# Accuracy of plane : 81.90 %
# Accuracy of   car : 92.70 %
# Accuracy of  bird : 65.30 %
# Accuracy of   cat : 62.50 %
# Accuracy of  deer : 84.60 %
# Accuracy of   dog : 70.70 %
# Accuracy of  frog : 90.60 %
# Accuracy of horse : 82.90 %
# Accuracy of  ship : 89.50 %
# Accuracy of truck : 88.70 %
# 80.94000000000001
# [Epoch : 71, Iter:    50] loss: 1.655
# [Epoch : 72, Iter:    50] loss: 1.655
# [Epoch : 73, Iter:    50] loss: 1.655
# [Epoch : 74, Iter:    50] loss: 1.652
# [Epoch : 75, Iter:    50] loss: 1.650
# [Epoch : 76, Iter:    50] loss: 1.653
# [Epoch : 77, Iter:    50] loss: 1.648
# [Epoch : 78, Iter:    50] loss: 1.648
# [Epoch : 79, Iter:    50] loss: 1.646
# [Epoch : 80, Iter:    50] loss: 1.646
# Start test
# Accuracy of plane : 86.60 %
# Accuracy of   car : 93.80 %
# Accuracy of  bird : 74.70 %
# Accuracy of   cat : 54.50 %
# Accuracy of  deer : 78.00 %
# Accuracy of   dog : 79.00 %
# Accuracy of  frog : 83.80 %
# Accuracy of horse : 88.50 %
# Accuracy of  ship : 86.40 %
# Accuracy of truck : 88.30 %
# 81.35999999999999
# [Epoch : 81, Iter:    50] loss: 1.648
# [Epoch : 82, Iter:    50] loss: 1.645
# [Epoch : 83, Iter:    50] loss: 1.643
# [Epoch : 84, Iter:    50] loss: 1.644
# [Epoch : 85, Iter:    50] loss: 1.642
# [Epoch : 86, Iter:    50] loss: 1.640
# [Epoch : 87, Iter:    50] loss: 1.644
# [Epoch : 88, Iter:    50] loss: 1.640
# [Epoch : 89, Iter:    50] loss: 1.640
# [Epoch : 90, Iter:    50] loss: 1.637
# Start test
# Accuracy of plane : 85.90 %
# Accuracy of   car : 94.10 %
# Accuracy of  bird : 81.20 %
# Accuracy of   cat : 61.40 %
# Accuracy of  deer : 78.20 %
# Accuracy of   dog : 75.20 %
# Accuracy of  frog : 86.90 %
# Accuracy of horse : 81.00 %
# Accuracy of  ship : 87.30 %
# Accuracy of truck : 86.40 %
# 81.76
# [Epoch : 91, Iter:    50] loss: 1.636
# [Epoch : 92, Iter:    50] loss: 1.634
# [Epoch : 93, Iter:    50] loss: 1.635
# [Epoch : 94, Iter:    50] loss: 1.635
# [Epoch : 95, Iter:    50] loss: 1.633
# [Epoch : 96, Iter:    50] loss: 1.635
# [Epoch : 97, Iter:    50] loss: 1.630
# [Epoch : 98, Iter:    50] loss: 1.627
# [Epoch : 99, Iter:    50] loss: 1.632
# [Epoch : 100, Iter:    50] loss: 1.629
# Start test
# Accuracy of plane : 86.90 %
# Accuracy of   car : 91.80 %
# Accuracy of  bird : 79.20 %
# Accuracy of   cat : 70.10 %
# Accuracy of  deer : 81.40 %
# Accuracy of   dog : 66.40 %
# Accuracy of  frog : 87.60 %
# Accuracy of horse : 82.70 %
# Accuracy of  ship : 92.50 %
# Accuracy of truck : 87.30 %
# 82.59
# [Epoch : 101, Iter:    50] loss: 1.628
# [Epoch : 102, Iter:    50] loss: 1.628
# [Epoch : 103, Iter:    50] loss: 1.627
# [Epoch : 104, Iter:    50] loss: 1.625
# [Epoch : 105, Iter:    50] loss: 1.624
# [Epoch : 106, Iter:    50] loss: 1.623
# [Epoch : 107, Iter:    50] loss: 1.623
# [Epoch : 108, Iter:    50] loss: 1.625
# [Epoch : 109, Iter:    50] loss: 1.622
# [Epoch : 110, Iter:    50] loss: 1.622
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 91.90 %
# Accuracy of  bird : 79.10 %
# Accuracy of   cat : 59.10 %
# Accuracy of  deer : 82.60 %
# Accuracy of   dog : 76.20 %
# Accuracy of  frog : 89.50 %
# Accuracy of horse : 89.60 %
# Accuracy of  ship : 90.80 %
# Accuracy of truck : 87.70 %
# 83.38
# [Epoch : 111, Iter:    50] loss: 1.621
# [Epoch : 112, Iter:    50] loss: 1.620
# [Epoch : 113, Iter:    50] loss: 1.619
# [Epoch : 114, Iter:    50] loss: 1.621
# [Epoch : 115, Iter:    50] loss: 1.620
# [Epoch : 116, Iter:    50] loss: 1.618
# [Epoch : 117, Iter:    50] loss: 1.617
# [Epoch : 118, Iter:    50] loss: 1.616
# [Epoch : 119, Iter:    50] loss: 1.618
# [Epoch : 120, Iter:    50] loss: 1.616
# Start test
# Accuracy of plane : 84.90 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 75.40 %
# Accuracy of   cat : 73.00 %
# Accuracy of  deer : 75.40 %
# Accuracy of   dog : 73.80 %
# Accuracy of  frog : 88.00 %
# Accuracy of horse : 88.40 %
# Accuracy of  ship : 92.30 %
# Accuracy of truck : 88.00 %
# 83.22999999999999
# [Epoch : 121, Iter:    50] loss: 1.614
# [Epoch : 122, Iter:    50] loss: 1.612
# [Epoch : 123, Iter:    50] loss: 1.614
# [Epoch : 124, Iter:    50] loss: 1.612
# [Epoch : 125, Iter:    50] loss: 1.613
# [Epoch : 126, Iter:    50] loss: 1.614
# [Epoch : 127, Iter:    50] loss: 1.611
# [Epoch : 128, Iter:    50] loss: 1.609
# [Epoch : 129, Iter:    50] loss: 1.611
# [Epoch : 130, Iter:    50] loss: 1.610
# Start test
# Accuracy of plane : 86.50 %
# Accuracy of   car : 93.50 %
# Accuracy of  bird : 71.00 %
# Accuracy of   cat : 62.80 %
# Accuracy of  deer : 81.20 %
# Accuracy of   dog : 77.20 %
# Accuracy of  frog : 93.00 %
# Accuracy of horse : 88.40 %
# Accuracy of  ship : 93.20 %
# Accuracy of truck : 88.90 %
# 83.57000000000001
# [Epoch : 131, Iter:    50] loss: 1.609
# [Epoch : 132, Iter:    50] loss: 1.608
# [Epoch : 133, Iter:    50] loss: 1.609
# [Epoch : 134, Iter:    50] loss: 1.607
# [Epoch : 135, Iter:    50] loss: 1.606
# [Epoch : 136, Iter:    50] loss: 1.606
# [Epoch : 137, Iter:    50] loss: 1.606
# [Epoch : 138, Iter:    50] loss: 1.606
# [Epoch : 139, Iter:    50] loss: 1.605
# [Epoch : 140, Iter:    50] loss: 1.603
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 93.30 %
# Accuracy of  bird : 71.70 %
# Accuracy of   cat : 69.90 %
# Accuracy of  deer : 81.90 %
# Accuracy of   dog : 79.30 %
# Accuracy of  frog : 89.10 %
# Accuracy of horse : 85.90 %
# Accuracy of  ship : 90.50 %
# Accuracy of truck : 90.00 %
# 83.89000000000001
# [Epoch : 141, Iter:    50] loss: 1.604
# [Epoch : 142, Iter:    50] loss: 1.603
# [Epoch : 143, Iter:    50] loss: 1.602
# [Epoch : 144, Iter:    50] loss: 1.602
# [Epoch : 145, Iter:    50] loss: 1.602
# [Epoch : 146, Iter:    50] loss: 1.601
# [Epoch : 147, Iter:    50] loss: 1.602
# [Epoch : 148, Iter:    50] loss: 1.601
# [Epoch : 149, Iter:    50] loss: 1.601
# [Epoch : 150, Iter:    50] loss: 1.598
# Start test
# Accuracy of plane : 88.10 %
# Accuracy of   car : 92.20 %
# Accuracy of  bird : 72.30 %
# Accuracy of   cat : 68.00 %
# Accuracy of  deer : 86.90 %
# Accuracy of   dog : 76.60 %
# Accuracy of  frog : 88.90 %
# Accuracy of horse : 87.30 %
# Accuracy of  ship : 91.40 %
# Accuracy of truck : 91.20 %
# 84.28999999999999
# [Epoch : 151, Iter:    50] loss: 1.602
# [Epoch : 152, Iter:    50] loss: 1.599
# [Epoch : 153, Iter:    50] loss: 1.599
# [Epoch : 154, Iter:    50] loss: 1.597
# [Epoch : 155, Iter:    50] loss: 1.598
# [Epoch : 156, Iter:    50] loss: 1.597
# [Epoch : 157, Iter:    50] loss: 1.599
# [Epoch : 158, Iter:    50] loss: 1.596
# [Epoch : 159, Iter:    50] loss: 1.597
# [Epoch : 160, Iter:    50] loss: 1.596
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 92.10 %
# Accuracy of  bird : 69.80 %
# Accuracy of   cat : 70.70 %
# Accuracy of  deer : 84.30 %
# Accuracy of   dog : 76.40 %
# Accuracy of  frog : 89.60 %
# Accuracy of horse : 90.00 %
# Accuracy of  ship : 91.10 %
# Accuracy of truck : 91.90 %
# 84.32
# [Epoch : 161, Iter:    50] loss: 1.596
# [Epoch : 162, Iter:    50] loss: 1.595
# [Epoch : 163, Iter:    50] loss: 1.594
# [Epoch : 164, Iter:    50] loss: 1.595
# [Epoch : 165, Iter:    50] loss: 1.594
# [Epoch : 166, Iter:    50] loss: 1.594
# [Epoch : 167, Iter:    50] loss: 1.593
# [Epoch : 168, Iter:    50] loss: 1.594
# [Epoch : 169, Iter:    50] loss: 1.592
# [Epoch : 170, Iter:    50] loss: 1.592
# Start test
# Accuracy of plane : 87.70 %
# Accuracy of   car : 93.40 %
# Accuracy of  bird : 74.70 %
# Accuracy of   cat : 67.50 %
# Accuracy of  deer : 83.60 %
# Accuracy of   dog : 78.20 %
# Accuracy of  frog : 91.10 %
# Accuracy of horse : 85.30 %
# Accuracy of  ship : 90.20 %
# Accuracy of truck : 91.20 %
# 84.29
# [Epoch : 171, Iter:    50] loss: 1.593
# [Epoch : 172, Iter:    50] loss: 1.592
# [Epoch : 173, Iter:    50] loss: 1.592
# [Epoch : 174, Iter:    50] loss: 1.592
# [Epoch : 175, Iter:    50] loss: 1.591
# [Epoch : 176, Iter:    50] loss: 1.591
# [Epoch : 177, Iter:    50] loss: 1.590
# [Epoch : 178, Iter:    50] loss: 1.590
# [Epoch : 179, Iter:    50] loss: 1.589
# [Epoch : 180, Iter:    50] loss: 1.589
# Start test
# Accuracy of plane : 86.90 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 74.80 %
# Accuracy of   cat : 72.40 %
# Accuracy of  deer : 83.70 %
# Accuracy of   dog : 74.40 %
# Accuracy of  frog : 89.40 %
# Accuracy of horse : 90.70 %
# Accuracy of  ship : 90.40 %
# Accuracy of truck : 91.50 %
# 84.73
# [Epoch : 181, Iter:    50] loss: 1.589
# [Epoch : 182, Iter:    50] loss: 1.588
# [Epoch : 183, Iter:    50] loss: 1.588
# [Epoch : 184, Iter:    50] loss: 1.588
# [Epoch : 185, Iter:    50] loss: 1.589
# [Epoch : 186, Iter:    50] loss: 1.588
# [Epoch : 187, Iter:    50] loss: 1.589
# [Epoch : 188, Iter:    50] loss: 1.589
# [Epoch : 189, Iter:    50] loss: 1.587
# [Epoch : 190, Iter:    50] loss: 1.586
# Start test
# Accuracy of plane : 88.30 %
# Accuracy of   car : 93.30 %
# Accuracy of  bird : 76.50 %
# Accuracy of   cat : 68.90 %
# Accuracy of  deer : 86.00 %
# Accuracy of   dog : 78.30 %
# Accuracy of  frog : 89.10 %
# Accuracy of horse : 88.90 %
# Accuracy of  ship : 91.40 %
# Accuracy of truck : 91.10 %
# 85.17999999999999
# [Epoch : 191, Iter:    50] loss: 1.586
# [Epoch : 192, Iter:    50] loss: 1.587
# [Epoch : 193, Iter:    50] loss: 1.586
# [Epoch : 194, Iter:    50] loss: 1.587
# [Epoch : 195, Iter:    50] loss: 1.586
# [Epoch : 196, Iter:    50] loss: 1.585
# [Epoch : 197, Iter:    50] loss: 1.585
# [Epoch : 198, Iter:    50] loss: 1.584
# [Epoch : 199, Iter:    50] loss: 1.586
# [Epoch : 200, Iter:    50] loss: 1.586
# Start test
# Accuracy of plane : 86.50 %
# Accuracy of   car : 93.00 %
# Accuracy of  bird : 75.80 %
# Accuracy of   cat : 68.10 %
# Accuracy of  deer : 84.80 %
# Accuracy of   dog : 79.60 %
# Accuracy of  frog : 89.90 %
# Accuracy of horse : 88.30 %
# Accuracy of  ship : 91.00 %
# Accuracy of truck : 91.80 %
# 84.88
# [Epoch : 201, Iter:    50] loss: 1.585
# [Epoch : 202, Iter:    50] loss: 1.585
# [Epoch : 203, Iter:    50] loss: 1.584
# [Epoch : 204, Iter:    50] loss: 1.583
# [Epoch : 205, Iter:    50] loss: 1.584
# [Epoch : 206, Iter:    50] loss: 1.584
# [Epoch : 207, Iter:    50] loss: 1.584
# [Epoch : 208, Iter:    50] loss: 1.582
# [Epoch : 209, Iter:    50] loss: 1.583
# [Epoch : 210, Iter:    50] loss: 1.583
# Start test
# Accuracy of plane : 88.20 %
# Accuracy of   car : 93.20 %
# Accuracy of  bird : 77.80 %
# Accuracy of   cat : 70.00 %
# Accuracy of  deer : 81.70 %
# Accuracy of   dog : 77.70 %
# Accuracy of  frog : 88.30 %
# Accuracy of horse : 90.90 %
# Accuracy of  ship : 90.90 %
# Accuracy of truck : 91.40 %
# 85.01
# [Epoch : 211, Iter:    50] loss: 1.583
# [Epoch : 212, Iter:    50] loss: 1.581
# [Epoch : 213, Iter:    50] loss: 1.583
# [Epoch : 214, Iter:    50] loss: 1.582
# [Epoch : 215, Iter:    50] loss: 1.582
# [Epoch : 216, Iter:    50] loss: 1.583
# [Epoch : 217, Iter:    50] loss: 1.581
# [Epoch : 218, Iter:    50] loss: 1.581
# [Epoch : 219, Iter:    50] loss: 1.581
# [Epoch : 220, Iter:    50] loss: 1.581
# Start test
# Accuracy of plane : 87.80 %
# Accuracy of   car : 93.70 %
# Accuracy of  bird : 81.00 %
# Accuracy of   cat : 70.60 %
# Accuracy of  deer : 84.40 %
# Accuracy of   dog : 75.90 %
# Accuracy of  frog : 89.50 %
# Accuracy of horse : 89.30 %
# Accuracy of  ship : 91.90 %
# Accuracy of truck : 89.70 %
# 85.38000000000001
# [Epoch : 221, Iter:    50] loss: 1.581
# [Epoch : 222, Iter:    50] loss: 1.581
# [Epoch : 223, Iter:    50] loss: 1.579
# [Epoch : 224, Iter:    50] loss: 1.580
# [Epoch : 225, Iter:    50] loss: 1.580
# [Epoch : 226, Iter:    50] loss: 1.580
# [Epoch : 227, Iter:    50] loss: 1.579
# [Epoch : 228, Iter:    50] loss: 1.579
# [Epoch : 229, Iter:    50] loss: 1.579
# [Epoch : 230, Iter:    50] loss: 1.579
# Start test
# Accuracy of plane : 88.70 %
# Accuracy of   car : 93.50 %
# Accuracy of  bird : 78.20 %
# Accuracy of   cat : 68.40 %
# Accuracy of  deer : 84.40 %
# Accuracy of   dog : 78.20 %
# Accuracy of  frog : 90.70 %
# Accuracy of horse : 90.10 %
# Accuracy of  ship : 91.00 %
# Accuracy of truck : 90.60 %
# 85.38000000000001
# [Epoch : 231, Iter:    50] loss: 1.578
# [Epoch : 232, Iter:    50] loss: 1.579
# [Epoch : 233, Iter:    50] loss: 1.579
# [Epoch : 234, Iter:    50] loss: 1.579
# [Epoch : 235, Iter:    50] loss: 1.578
# [Epoch : 236, Iter:    50] loss: 1.578
# [Epoch : 237, Iter:    50] loss: 1.579
# [Epoch : 238, Iter:    50] loss: 1.578
# [Epoch : 239, Iter:    50] loss: 1.576
# [Epoch : 240, Iter:    50] loss: 1.576
# Start test
# Accuracy of plane : 87.20 %
# Accuracy of   car : 94.30 %
# Accuracy of  bird : 76.60 %
# Accuracy of   cat : 70.70 %
# Accuracy of  deer : 86.30 %
# Accuracy of   dog : 76.20 %
# Accuracy of  frog : 88.90 %
# Accuracy of horse : 89.60 %
# Accuracy of  ship : 91.10 %
# Accuracy of truck : 90.60 %
# 85.15
# [Epoch : 241, Iter:    50] loss: 1.577
# [Epoch : 242, Iter:    50] loss: 1.578
# [Epoch : 243, Iter:    50] loss: 1.578
# [Epoch : 244, Iter:    50] loss: 1.578
# [Epoch : 245, Iter:    50] loss: 1.577
# [Epoch : 246, Iter:    50] loss: 1.577
# [Epoch : 247, Iter:    50] loss: 1.577
# [Epoch : 248, Iter:    50] loss: 1.577
# [Epoch : 249, Iter:    50] loss: 1.577
# [Epoch : 250, Iter:    50] loss: 1.577
# Start test
# Accuracy of plane : 87.10 %
# Accuracy of   car : 93.30 %
# Accuracy of  bird : 76.60 %
# Accuracy of   cat : 69.40 %
# Accuracy of  deer : 86.60 %
# Accuracy of   dog : 77.50 %
# Accuracy of  frog : 90.90 %
# Accuracy of horse : 89.30 %
# Accuracy of  ship : 91.70 %
# Accuracy of truck : 91.00 %
# 85.34
# [Epoch : 251, Iter:    50] loss: 1.578
# [Epoch : 252, Iter:    50] loss: 1.577
# [Epoch : 253, Iter:    50] loss: 1.576
# [Epoch : 254, Iter:    50] loss: 1.576
# [Epoch : 255, Iter:    50] loss: 1.577
# [Epoch : 256, Iter:    50] loss: 1.576
# [Epoch : 257, Iter:    50] loss: 1.576
# [Epoch : 258, Iter:    50] loss: 1.575
# [Epoch : 259, Iter:    50] loss: 1.575
# [Epoch : 260, Iter:    50] loss: 1.575
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 93.20 %
# Accuracy of  bird : 78.10 %
# Accuracy of   cat : 71.80 %
# Accuracy of  deer : 85.70 %
# Accuracy of   dog : 76.80 %
# Accuracy of  frog : 90.00 %
# Accuracy of horse : 89.30 %
# Accuracy of  ship : 91.70 %
# Accuracy of truck : 91.10 %
# 85.50000000000001
# [Epoch : 261, Iter:    50] loss: 1.575
# [Epoch : 262, Iter:    50] loss: 1.576
# [Epoch : 263, Iter:    50] loss: 1.576
# [Epoch : 264, Iter:    50] loss: 1.576
# [Epoch : 265, Iter:    50] loss: 1.576
# [Epoch : 266, Iter:    50] loss: 1.575
# [Epoch : 267, Iter:    50] loss: 1.575
# [Epoch : 268, Iter:    50] loss: 1.575
# [Epoch : 269, Iter:    50] loss: 1.575
# [Epoch : 270, Iter:    50] loss: 1.575
# Start test
# Accuracy of plane : 87.30 %
# Accuracy of   car : 93.50 %
# Accuracy of  bird : 77.20 %
# Accuracy of   cat : 69.80 %
# Accuracy of  deer : 83.80 %
# Accuracy of   dog : 76.80 %
# Accuracy of  frog : 90.90 %
# Accuracy of horse : 90.10 %
# Accuracy of  ship : 91.70 %
# Accuracy of truck : 91.00 %
# 85.21000000000001
# [Epoch : 271, Iter:    50] loss: 1.575
# [Epoch : 272, Iter:    50] loss: 1.575
# [Epoch : 273, Iter:    50] loss: 1.574
# [Epoch : 274, Iter:    50] loss: 1.574
# [Epoch : 275, Iter:    50] loss: 1.576
# [Epoch : 276, Iter:    50] loss: 1.575
# [Epoch : 277, Iter:    50] loss: 1.574
# [Epoch : 278, Iter:    50] loss: 1.573
# [Epoch : 279, Iter:    50] loss: 1.574
# [Epoch : 280, Iter:    50] loss: 1.574
# Start test
# Accuracy of plane : 87.60 %
# Accuracy of   car : 93.00 %
# Accuracy of  bird : 78.20 %
# Accuracy of   cat : 69.20 %
# Accuracy of  deer : 85.40 %
# Accuracy of   dog : 78.10 %
# Accuracy of  frog : 89.60 %
# Accuracy of horse : 90.50 %
# Accuracy of  ship : 92.10 %
# Accuracy of truck : 91.00 %
# 85.47
# [Epoch : 281, Iter:    50] loss: 1.574
# [Epoch : 282, Iter:    50] loss: 1.573
# [Epoch : 283, Iter:    50] loss: 1.574
# [Epoch : 284, Iter:    50] loss: 1.573
# [Epoch : 285, Iter:    50] loss: 1.574
# [Epoch : 286, Iter:    50] loss: 1.575
# [Epoch : 287, Iter:    50] loss: 1.573
# [Epoch : 288, Iter:    50] loss: 1.573
# [Epoch : 289, Iter:    50] loss: 1.574
# [Epoch : 290, Iter:    50] loss: 1.573
# Start test
# Accuracy of plane : 88.10 %
# Accuracy of   car : 92.60 %
# Accuracy of  bird : 78.20 %
# Accuracy of   cat : 71.60 %
# Accuracy of  deer : 84.30 %
# Accuracy of   dog : 75.90 %
# Accuracy of  frog : 90.40 %
# Accuracy of horse : 89.00 %
# Accuracy of  ship : 92.00 %
# Accuracy of truck : 91.20 %
# 85.33000000000001
# [Epoch : 291, Iter:    50] loss: 1.572
# [Epoch : 292, Iter:    50] loss: 1.573
# [Epoch : 293, Iter:    50] loss: 1.573
# [Epoch : 294, Iter:    50] loss: 1.573
# [Epoch : 295, Iter:    50] loss: 1.573
# [Epoch : 296, Iter:    50] loss: 1.573
# [Epoch : 297, Iter:    50] loss: 1.573
# [Epoch : 298, Iter:    50] loss: 1.573
# [Epoch : 299, Iter:    50] loss: 1.572
# [Epoch : 300, Iter:    50] loss: 1.572
# Start test
# Accuracy of plane : 87.40 %
# Accuracy of   car : 93.20 %
# Accuracy of  bird : 78.40 %
# Accuracy of   cat : 68.90 %
# Accuracy of  deer : 85.90 %
# Accuracy of   dog : 78.50 %
# Accuracy of  frog : 89.60 %
# Accuracy of horse : 89.90 %
# Accuracy of  ship : 92.40 %
# Accuracy of truck : 90.80 %
# 85.49999999999999
# Net_MCDO
# Let's use 4 GPUs!
#   0%|          | 0/300 [00:00<?, ?it/s]
# [Epoch : 1, Iter:    50] loss: 2.181
# [Epoch : 2, Iter:    50] loss: 2.060
# [Epoch : 3, Iter:    50] loss: 2.016
# [Epoch : 4, Iter:    50] loss: 1.988
# [Epoch : 5, Iter:    50] loss: 1.951
# [Epoch : 6, Iter:    50] loss: 1.929
# [Epoch : 7, Iter:    50] loss: 1.898
# [Epoch : 8, Iter:    50] loss: 1.876
# [Epoch : 9, Iter:    50] loss: 1.868
# [Epoch : 10, Iter:    50] loss: 1.850
# Start test
# Accuracy of plane : 85.00 %
# Accuracy of   car : 82.10 %
# Accuracy of  bird : 45.80 %
# Accuracy of   cat : 37.20 %
# Accuracy of  deer : 49.00 %
# Accuracy of   dog : 61.50 %
# Accuracy of  frog : 73.70 %
# Accuracy of horse : 72.90 %
# Accuracy of  ship : 70.80 %
# Accuracy of truck : 71.30 %
# 64.92999999999999
# [Epoch : 11, Iter:    50] loss: 1.840
# [Epoch : 12, Iter:    50] loss: 1.834
# [Epoch : 13, Iter:    50] loss: 1.821
# [Epoch : 14, Iter:    50] loss: 1.813
# [Epoch : 15, Iter:    50] loss: 1.811
# [Epoch : 16, Iter:    50] loss: 1.798
# [Epoch : 17, Iter:    50] loss: 1.793
# [Epoch : 18, Iter:    50] loss: 1.787
# [Epoch : 19, Iter:    50] loss: 1.781
# [Epoch : 20, Iter:    50] loss: 1.778
# Start test
# Accuracy of plane : 85.10 %
# Accuracy of   car : 91.50 %
# Accuracy of  bird : 54.70 %
# Accuracy of   cat : 50.40 %
# Accuracy of  deer : 47.10 %
# Accuracy of   dog : 73.00 %
# Accuracy of  frog : 82.40 %
# Accuracy of horse : 74.60 %
# Accuracy of  ship : 71.10 %
# Accuracy of truck : 71.70 %
# 70.16
# [Epoch : 21, Iter:    50] loss: 1.773
# [Epoch : 22, Iter:    50] loss: 1.770
# [Epoch : 23, Iter:    50] loss: 1.760
# [Epoch : 24, Iter:    50] loss: 1.759
# [Epoch : 25, Iter:    50] loss: 1.757
# [Epoch : 26, Iter:    50] loss: 1.751
# [Epoch : 27, Iter:    50] loss: 1.750
# [Epoch : 28, Iter:    50] loss: 1.744
# [Epoch : 29, Iter:    50] loss: 1.742
# [Epoch : 30, Iter:    50] loss: 1.738
# Start test
# Accuracy of plane : 87.60 %
# Accuracy of   car : 88.00 %
# Accuracy of  bird : 65.30 %
# Accuracy of   cat : 54.90 %
# Accuracy of  deer : 65.50 %
# Accuracy of   dog : 67.10 %
# Accuracy of  frog : 86.40 %
# Accuracy of horse : 77.30 %
# Accuracy of  ship : 82.10 %
# Accuracy of truck : 79.40 %
# 75.35999999999999
# [Epoch : 31, Iter:    50] loss: 1.735
# [Epoch : 32, Iter:    50] loss: 1.734
# [Epoch : 33, Iter:    50] loss: 1.729
# [Epoch : 34, Iter:    50] loss: 1.731
# [Epoch : 35, Iter:    50] loss: 1.725
# [Epoch : 36, Iter:    50] loss: 1.723
# [Epoch : 37, Iter:    50] loss: 1.721
# [Epoch : 38, Iter:    50] loss: 1.719
# [Epoch : 39, Iter:    50] loss: 1.720
# [Epoch : 40, Iter:    50] loss: 1.715
# Start test
# Accuracy of plane : 80.40 %
# Accuracy of   car : 84.90 %
# Accuracy of  bird : 63.70 %
# Accuracy of   cat : 54.20 %
# Accuracy of  deer : 70.30 %
# Accuracy of   dog : 76.20 %
# Accuracy of  frog : 88.00 %
# Accuracy of horse : 82.30 %
# Accuracy of  ship : 90.50 %
# Accuracy of truck : 88.40 %
# 77.89
# [Epoch : 41, Iter:    50] loss: 1.711
# [Epoch : 42, Iter:    50] loss: 1.711
# [Epoch : 43, Iter:    50] loss: 1.709
# [Epoch : 44, Iter:    50] loss: 1.706
# [Epoch : 45, Iter:    50] loss: 1.706
# [Epoch : 46, Iter:    50] loss: 1.705
# [Epoch : 47, Iter:    50] loss: 1.704
# [Epoch : 48, Iter:    50] loss: 1.700
# [Epoch : 49, Iter:    50] loss: 1.700
# [Epoch : 50, Iter:    50] loss: 1.696
# Start test
# Accuracy of plane : 86.50 %
# Accuracy of   car : 92.80 %
# Accuracy of  bird : 63.00 %
# Accuracy of   cat : 58.70 %
# Accuracy of  deer : 77.90 %
# Accuracy of   dog : 77.30 %
# Accuracy of  frog : 83.10 %
# Accuracy of horse : 82.30 %
# Accuracy of  ship : 84.90 %
# Accuracy of truck : 84.70 %
# 79.11999999999999
# [Epoch : 51, Iter:    50] loss: 1.697
# [Epoch : 52, Iter:    50] loss: 1.691
# [Epoch : 53, Iter:    50] loss: 1.696
# [Epoch : 54, Iter:    50] loss: 1.697
# [Epoch : 55, Iter:    50] loss: 1.688
# [Epoch : 56, Iter:    50] loss: 1.692
# [Epoch : 57, Iter:    50] loss: 1.689
# [Epoch : 58, Iter:    50] loss: 1.687
# [Epoch : 59, Iter:    50] loss: 1.686
# [Epoch : 60, Iter:    50] loss: 1.681
# Start test
# Accuracy of plane : 87.10 %
# Accuracy of   car : 91.20 %
# Accuracy of  bird : 71.50 %
# Accuracy of   cat : 66.00 %
# Accuracy of  deer : 78.70 %
# Accuracy of   dog : 72.50 %
# Accuracy of  frog : 83.80 %
# Accuracy of horse : 78.70 %
# Accuracy of  ship : 85.60 %
# Accuracy of truck : 82.60 %
# 79.77000000000001
# [Epoch : 61, Iter:    50] loss: 1.684
# [Epoch : 62, Iter:    50] loss: 1.682
# [Epoch : 63, Iter:    50] loss: 1.679
# [Epoch : 64, Iter:    50] loss: 1.682
# [Epoch : 65, Iter:    50] loss: 1.677
# [Epoch : 66, Iter:    50] loss: 1.676
# [Epoch : 67, Iter:    50] loss: 1.673
# [Epoch : 68, Iter:    50] loss: 1.675
# [Epoch : 69, Iter:    50] loss: 1.671
# [Epoch : 70, Iter:    50] loss: 1.670
# Start test
# Accuracy of plane : 85.20 %
# Accuracy of   car : 88.00 %
# Accuracy of  bird : 74.50 %
# Accuracy of   cat : 59.50 %
# Accuracy of  deer : 83.30 %
# Accuracy of   dog : 69.60 %
# Accuracy of  frog : 90.70 %
# Accuracy of horse : 80.10 %
# Accuracy of  ship : 91.50 %
# Accuracy of truck : 84.00 %
# 80.64
# [Epoch : 71, Iter:    50] loss: 1.669
# [Epoch : 72, Iter:    50] loss: 1.669
# [Epoch : 73, Iter:    50] loss: 1.667
# [Epoch : 74, Iter:    50] loss: 1.670
# [Epoch : 75, Iter:    50] loss: 1.664
# [Epoch : 76, Iter:    50] loss: 1.665
# [Epoch : 77, Iter:    50] loss: 1.669
# [Epoch : 78, Iter:    50] loss: 1.664
# [Epoch : 79, Iter:    50] loss: 1.663
# [Epoch : 80, Iter:    50] loss: 1.660
# Start test
# Accuracy of plane : 84.00 %
# Accuracy of   car : 89.40 %
# Accuracy of  bird : 66.70 %
# Accuracy of   cat : 64.40 %
# Accuracy of  deer : 83.60 %
# Accuracy of   dog : 71.40 %
# Accuracy of  frog : 90.40 %
# Accuracy of horse : 84.40 %
# Accuracy of  ship : 91.40 %
# Accuracy of truck : 91.90 %
# 81.75999999999999
# [Epoch : 81, Iter:    50] loss: 1.660
# [Epoch : 82, Iter:    50] loss: 1.659
# [Epoch : 83, Iter:    50] loss: 1.658
# [Epoch : 84, Iter:    50] loss: 1.660
# [Epoch : 85, Iter:    50] loss: 1.660
# [Epoch : 86, Iter:    50] loss: 1.655
# [Epoch : 87, Iter:    50] loss: 1.654
# [Epoch : 88, Iter:    50] loss: 1.654
# [Epoch : 89, Iter:    50] loss: 1.654
# [Epoch : 90, Iter:    50] loss: 1.655
# Start test
# Accuracy of plane : 87.40 %
# Accuracy of   car : 93.90 %
# Accuracy of  bird : 71.70 %
# Accuracy of   cat : 66.90 %
# Accuracy of  deer : 84.40 %
# Accuracy of   dog : 72.10 %
# Accuracy of  frog : 87.60 %
# Accuracy of horse : 85.60 %
# Accuracy of  ship : 87.90 %
# Accuracy of truck : 85.20 %
# 82.27000000000001
# [Epoch : 91, Iter:    50] loss: 1.653
# [Epoch : 92, Iter:    50] loss: 1.652
# [Epoch : 93, Iter:    50] loss: 1.651
# [Epoch : 94, Iter:    50] loss: 1.649
# [Epoch : 95, Iter:    50] loss: 1.649
# [Epoch : 96, Iter:    50] loss: 1.650
# [Epoch : 97, Iter:    50] loss: 1.650
# [Epoch : 98, Iter:    50] loss: 1.649
# [Epoch : 99, Iter:    50] loss: 1.648
# [Epoch : 100, Iter:    50] loss: 1.646
# Start test
# Accuracy of plane : 82.50 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 75.20 %
# Accuracy of   cat : 63.40 %
# Accuracy of  deer : 85.20 %
# Accuracy of   dog : 74.20 %
# Accuracy of  frog : 88.60 %
# Accuracy of horse : 86.30 %
# Accuracy of  ship : 90.50 %
# Accuracy of truck : 88.10 %
# 82.71000000000001
# [Epoch : 101, Iter:    50] loss: 1.646
# [Epoch : 102, Iter:    50] loss: 1.646
# [Epoch : 103, Iter:    50] loss: 1.646
# [Epoch : 104, Iter:    50] loss: 1.644
# [Epoch : 105, Iter:    50] loss: 1.644
# [Epoch : 106, Iter:    50] loss: 1.641
# [Epoch : 107, Iter:    50] loss: 1.640
# [Epoch : 108, Iter:    50] loss: 1.641
# [Epoch : 109, Iter:    50] loss: 1.638
# [Epoch : 110, Iter:    50] loss: 1.641
# Start test
# Accuracy of plane : 85.90 %
# Accuracy of   car : 91.50 %
# Accuracy of  bird : 68.40 %
# Accuracy of   cat : 66.40 %
# Accuracy of  deer : 78.80 %
# Accuracy of   dog : 78.00 %
# Accuracy of  frog : 90.00 %
# Accuracy of horse : 84.10 %
# Accuracy of  ship : 88.80 %
# Accuracy of truck : 90.80 %
# 82.27
# [Epoch : 111, Iter:    50] loss: 1.637
# [Epoch : 112, Iter:    50] loss: 1.642
# [Epoch : 113, Iter:    50] loss: 1.639
# [Epoch : 114, Iter:    50] loss: 1.637
# [Epoch : 115, Iter:    50] loss: 1.635
# [Epoch : 116, Iter:    50] loss: 1.636
# [Epoch : 117, Iter:    50] loss: 1.637
# [Epoch : 118, Iter:    50] loss: 1.634
# [Epoch : 119, Iter:    50] loss: 1.633
# [Epoch : 120, Iter:    50] loss: 1.633
# Start test
# Accuracy of plane : 86.30 %
# Accuracy of   car : 92.80 %
# Accuracy of  bird : 73.60 %
# Accuracy of   cat : 71.10 %
# Accuracy of  deer : 75.80 %
# Accuracy of   dog : 70.50 %
# Accuracy of  frog : 89.50 %
# Accuracy of horse : 88.80 %
# Accuracy of  ship : 89.60 %
# Accuracy of truck : 92.60 %
# 83.06
# [Epoch : 121, Iter:    50] loss: 1.632
# [Epoch : 122, Iter:    50] loss: 1.634
# [Epoch : 123, Iter:    50] loss: 1.632
# [Epoch : 124, Iter:    50] loss: 1.633
# [Epoch : 125, Iter:    50] loss: 1.632
# [Epoch : 126, Iter:    50] loss: 1.631
# [Epoch : 127, Iter:    50] loss: 1.632
# [Epoch : 128, Iter:    50] loss: 1.630
# [Epoch : 129, Iter:    50] loss: 1.629
# [Epoch : 130, Iter:    50] loss: 1.627
# Start test
# Accuracy of plane : 88.40 %
# Accuracy of   car : 92.10 %
# Accuracy of  bird : 75.60 %
# Accuracy of   cat : 66.30 %
# Accuracy of  deer : 82.90 %
# Accuracy of   dog : 73.10 %
# Accuracy of  frog : 89.60 %
# Accuracy of horse : 90.80 %
# Accuracy of  ship : 90.00 %
# Accuracy of truck : 92.30 %
# 84.10999999999999
# [Epoch : 131, Iter:    50] loss: 1.628
# [Epoch : 132, Iter:    50] loss: 1.629
# [Epoch : 133, Iter:    50] loss: 1.627
# [Epoch : 134, Iter:    50] loss: 1.627
# [Epoch : 135, Iter:    50] loss: 1.627
# [Epoch : 136, Iter:    50] loss: 1.627
# [Epoch : 137, Iter:    50] loss: 1.625
# [Epoch : 138, Iter:    50] loss: 1.625
# [Epoch : 139, Iter:    50] loss: 1.624
# [Epoch : 140, Iter:    50] loss: 1.625
# Start test
# Accuracy of plane : 87.60 %
# Accuracy of   car : 89.10 %
# Accuracy of  bird : 75.10 %
# Accuracy of   cat : 65.30 %
# Accuracy of  deer : 90.30 %
# Accuracy of   dog : 76.60 %
# Accuracy of  frog : 86.20 %
# Accuracy of horse : 87.30 %
# Accuracy of  ship : 89.90 %
# Accuracy of truck : 92.30 %
# 83.97
# [Epoch : 141, Iter:    50] loss: 1.625
# [Epoch : 142, Iter:    50] loss: 1.624
# [Epoch : 143, Iter:    50] loss: 1.623
# [Epoch : 144, Iter:    50] loss: 1.621
# [Epoch : 145, Iter:    50] loss: 1.622
# [Epoch : 146, Iter:    50] loss: 1.622
# [Epoch : 147, Iter:    50] loss: 1.622
# [Epoch : 148, Iter:    50] loss: 1.620
# [Epoch : 149, Iter:    50] loss: 1.620
# [Epoch : 150, Iter:    50] loss: 1.622
# Start test
# Accuracy of plane : 87.60 %
# Accuracy of   car : 92.60 %
# Accuracy of  bird : 69.30 %
# Accuracy of   cat : 75.10 %
# Accuracy of  deer : 81.20 %
# Accuracy of   dog : 71.20 %
# Accuracy of  frog : 90.10 %
# Accuracy of horse : 89.80 %
# Accuracy of  ship : 91.30 %
# Accuracy of truck : 90.90 %
# 83.90999999999998
# [Epoch : 151, Iter:    50] loss: 1.620
# [Epoch : 152, Iter:    50] loss: 1.621
# [Epoch : 153, Iter:    50] loss: 1.619
# [Epoch : 154, Iter:    50] loss: 1.618
# [Epoch : 155, Iter:    50] loss: 1.619
# [Epoch : 156, Iter:    50] loss: 1.618
# [Epoch : 157, Iter:    50] loss: 1.619
# [Epoch : 158, Iter:    50] loss: 1.617
# [Epoch : 159, Iter:    50] loss: 1.618
# [Epoch : 160, Iter:    50] loss: 1.617
# Start test
# Accuracy of plane : 89.00 %
# Accuracy of   car : 93.40 %
# Accuracy of  bird : 71.40 %
# Accuracy of   cat : 65.70 %
# Accuracy of  deer : 82.70 %
# Accuracy of   dog : 77.30 %
# Accuracy of  frog : 90.70 %
# Accuracy of horse : 90.90 %
# Accuracy of  ship : 89.50 %
# Accuracy of truck : 90.30 %
# 84.09
# [Epoch : 161, Iter:    50] loss: 1.616
# [Epoch : 162, Iter:    50] loss: 1.616
# [Epoch : 163, Iter:    50] loss: 1.615
# [Epoch : 164, Iter:    50] loss: 1.616
# [Epoch : 165, Iter:    50] loss: 1.616
# [Epoch : 166, Iter:    50] loss: 1.614
# [Epoch : 167, Iter:    50] loss: 1.613
# [Epoch : 168, Iter:    50] loss: 1.615
# [Epoch : 169, Iter:    50] loss: 1.616
# [Epoch : 170, Iter:    50] loss: 1.615
# Start test
# Accuracy of plane : 85.90 %
# Accuracy of   car : 92.60 %
# Accuracy of  bird : 76.70 %
# Accuracy of   cat : 71.80 %
# Accuracy of  deer : 83.50 %
# Accuracy of   dog : 76.60 %
# Accuracy of  frog : 89.40 %
# Accuracy of horse : 87.40 %
# Accuracy of  ship : 90.80 %
# Accuracy of truck : 92.30 %
# 84.69999999999999
# [Epoch : 171, Iter:    50] loss: 1.614
# [Epoch : 172, Iter:    50] loss: 1.612
# [Epoch : 173, Iter:    50] loss: 1.612
# [Epoch : 174, Iter:    50] loss: 1.614
# [Epoch : 175, Iter:    50] loss: 1.611
# [Epoch : 176, Iter:    50] loss: 1.613
# [Epoch : 177, Iter:    50] loss: 1.611
# [Epoch : 178, Iter:    50] loss: 1.612
# [Epoch : 179, Iter:    50] loss: 1.611
# [Epoch : 180, Iter:    50] loss: 1.611
# Start test
# Accuracy of plane : 89.20 %
# Accuracy of   car : 92.80 %
# Accuracy of  bird : 78.80 %
# Accuracy of   cat : 67.40 %
# Accuracy of  deer : 83.40 %
# Accuracy of   dog : 74.30 %
# Accuracy of  frog : 90.20 %
# Accuracy of horse : 90.90 %
# Accuracy of  ship : 91.40 %
# Accuracy of truck : 90.20 %
# 84.86
# [Epoch : 181, Iter:    50] loss: 1.610
# [Epoch : 182, Iter:    50] loss: 1.610
# [Epoch : 183, Iter:    50] loss: 1.610
# [Epoch : 184, Iter:    50] loss: 1.611
# [Epoch : 185, Iter:    50] loss: 1.609
# [Epoch : 186, Iter:    50] loss: 1.609
# [Epoch : 187, Iter:    50] loss: 1.609
# [Epoch : 188, Iter:    50] loss: 1.609
# [Epoch : 189, Iter:    50] loss: 1.609
# [Epoch : 190, Iter:    50] loss: 1.610
# Start test
# Accuracy of plane : 88.90 %
# Accuracy of   car : 93.00 %
# Accuracy of  bird : 79.40 %
# Accuracy of   cat : 68.70 %
# Accuracy of  deer : 81.50 %
# Accuracy of   dog : 76.00 %
# Accuracy of  frog : 90.80 %
# Accuracy of horse : 90.10 %
# Accuracy of  ship : 91.80 %
# Accuracy of truck : 90.10 %
# 85.03
# [Epoch : 191, Iter:    50] loss: 1.607
# [Epoch : 192, Iter:    50] loss: 1.608
# [Epoch : 193, Iter:    50] loss: 1.608
# [Epoch : 194, Iter:    50] loss: 1.609
# [Epoch : 195, Iter:    50] loss: 1.608
# [Epoch : 196, Iter:    50] loss: 1.609
# [Epoch : 197, Iter:    50] loss: 1.608
# [Epoch : 198, Iter:    50] loss: 1.607
# [Epoch : 199, Iter:    50] loss: 1.607
# [Epoch : 200, Iter:    50] loss: 1.607
# Start test
# Accuracy of plane : 90.00 %
# Accuracy of   car : 92.40 %
# Accuracy of  bird : 75.40 %
# Accuracy of   cat : 68.50 %
# Accuracy of  deer : 85.70 %
# Accuracy of   dog : 74.70 %
# Accuracy of  frog : 90.60 %
# Accuracy of horse : 89.80 %
# Accuracy of  ship : 90.70 %
# Accuracy of truck : 90.30 %
# 84.80999999999999
# [Epoch : 201, Iter:    50] loss: 1.608
# [Epoch : 202, Iter:    50] loss: 1.606
# [Epoch : 203, Iter:    50] loss: 1.608
# [Epoch : 204, Iter:    50] loss: 1.606
# [Epoch : 205, Iter:    50] loss: 1.606
# [Epoch : 206, Iter:    50] loss: 1.606
# [Epoch : 207, Iter:    50] loss: 1.605
# [Epoch : 208, Iter:    50] loss: 1.606
# [Epoch : 209, Iter:    50] loss: 1.606
# [Epoch : 210, Iter:    50] loss: 1.605
# Start test
# Accuracy of plane : 89.00 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 74.50 %
# Accuracy of   cat : 68.70 %
# Accuracy of  deer : 83.90 %
# Accuracy of   dog : 77.80 %
# Accuracy of  frog : 90.80 %
# Accuracy of horse : 88.90 %
# Accuracy of  ship : 91.60 %
# Accuracy of truck : 90.30 %
# 84.85999999999999
# [Epoch : 211, Iter:    50] loss: 1.605
# [Epoch : 212, Iter:    50] loss: 1.605
# [Epoch : 213, Iter:    50] loss: 1.605
# [Epoch : 214, Iter:    50] loss: 1.604
# [Epoch : 215, Iter:    50] loss: 1.605
# [Epoch : 216, Iter:    50] loss: 1.603
# [Epoch : 217, Iter:    50] loss: 1.604
# [Epoch : 218, Iter:    50] loss: 1.603
# [Epoch : 219, Iter:    50] loss: 1.605
# [Epoch : 220, Iter:    50] loss: 1.602
# Start test
# Accuracy of plane : 91.50 %
# Accuracy of   car : 92.20 %
# Accuracy of  bird : 74.30 %
# Accuracy of   cat : 70.00 %
# Accuracy of  deer : 84.20 %
# Accuracy of   dog : 77.90 %
# Accuracy of  frog : 90.40 %
# Accuracy of horse : 89.60 %
# Accuracy of  ship : 91.30 %
# Accuracy of truck : 90.00 %
# 85.14
# [Epoch : 221, Iter:    50] loss: 1.602
# [Epoch : 222, Iter:    50] loss: 1.603
# [Epoch : 223, Iter:    50] loss: 1.603
# [Epoch : 224, Iter:    50] loss: 1.603
# [Epoch : 225, Iter:    50] loss: 1.604
# [Epoch : 226, Iter:    50] loss: 1.603
# [Epoch : 227, Iter:    50] loss: 1.603
# [Epoch : 228, Iter:    50] loss: 1.603
# [Epoch : 229, Iter:    50] loss: 1.603
# [Epoch : 230, Iter:    50] loss: 1.601
# Start test
# Accuracy of plane : 89.40 %
# Accuracy of   car : 90.70 %
# Accuracy of  bird : 76.60 %
# Accuracy of   cat : 69.00 %
# Accuracy of  deer : 86.00 %
# Accuracy of   dog : 75.50 %
# Accuracy of  frog : 89.70 %
# Accuracy of horse : 91.20 %
# Accuracy of  ship : 92.20 %
# Accuracy of truck : 92.00 %
# 85.23
# [Epoch : 231, Iter:    50] loss: 1.602
# [Epoch : 232, Iter:    50] loss: 1.602
# [Epoch : 233, Iter:    50] loss: 1.603
# [Epoch : 234, Iter:    50] loss: 1.602
# [Epoch : 235, Iter:    50] loss: 1.602
# [Epoch : 236, Iter:    50] loss: 1.601
# [Epoch : 237, Iter:    50] loss: 1.601
# [Epoch : 238, Iter:    50] loss: 1.601
# [Epoch : 239, Iter:    50] loss: 1.601
# [Epoch : 240, Iter:    50] loss: 1.600
# Start test
# Accuracy of plane : 89.20 %
# Accuracy of   car : 92.30 %
# Accuracy of  bird : 74.80 %
# Accuracy of   cat : 68.20 %
# Accuracy of  deer : 84.70 %
# Accuracy of   dog : 76.60 %
# Accuracy of  frog : 92.00 %
# Accuracy of horse : 90.40 %
# Accuracy of  ship : 91.40 %
# Accuracy of truck : 92.80 %
# 85.24
# [Epoch : 241, Iter:    50] loss: 1.600
# [Epoch : 242, Iter:    50] loss: 1.601
# [Epoch : 243, Iter:    50] loss: 1.600
# [Epoch : 244, Iter:    50] loss: 1.601
# [Epoch : 245, Iter:    50] loss: 1.599
# [Epoch : 246, Iter:    50] loss: 1.601
# [Epoch : 247, Iter:    50] loss: 1.600
# [Epoch : 248, Iter:    50] loss: 1.599
# [Epoch : 249, Iter:    50] loss: 1.600
# [Epoch : 250, Iter:    50] loss: 1.600
# Start test
# Accuracy of plane : 89.40 %
# Accuracy of   car : 91.90 %
# Accuracy of  bird : 78.80 %
# Accuracy of   cat : 71.70 %
# Accuracy of  deer : 85.50 %
# Accuracy of   dog : 75.40 %
# Accuracy of  frog : 90.30 %
# Accuracy of horse : 88.60 %
# Accuracy of  ship : 91.70 %
# Accuracy of truck : 90.80 %
# 85.41
# [Epoch : 251, Iter:    50] loss: 1.599
# [Epoch : 252, Iter:    50] loss: 1.600
# [Epoch : 253, Iter:    50] loss: 1.599
# [Epoch : 254, Iter:    50] loss: 1.599
# [Epoch : 255, Iter:    50] loss: 1.599
# [Epoch : 256, Iter:    50] loss: 1.598
# [Epoch : 257, Iter:    50] loss: 1.599
# [Epoch : 258, Iter:    50] loss: 1.599
# [Epoch : 259, Iter:    50] loss: 1.598
# [Epoch : 260, Iter:    50] loss: 1.599
# Start test
# Accuracy of plane : 89.20 %
# Accuracy of   car : 93.00 %
# Accuracy of  bird : 75.80 %
# Accuracy of   cat : 70.70 %
# Accuracy of  deer : 84.50 %
# Accuracy of   dog : 76.10 %
# Accuracy of  frog : 90.60 %
# Accuracy of horse : 90.20 %
# Accuracy of  ship : 92.30 %
# Accuracy of truck : 90.70 %
# 85.30999999999999
# [Epoch : 261, Iter:    50] loss: 1.599
# [Epoch : 262, Iter:    50] loss: 1.599
# [Epoch : 263, Iter:    50] loss: 1.597
# [Epoch : 264, Iter:    50] loss: 1.598
# [Epoch : 265, Iter:    50] loss: 1.598
# [Epoch : 266, Iter:    50] loss: 1.599
# [Epoch : 267, Iter:    50] loss: 1.599
# [Epoch : 268, Iter:    50] loss: 1.598
# [Epoch : 269, Iter:    50] loss: 1.598
# [Epoch : 270, Iter:    50] loss: 1.598
# Start test
# Accuracy of plane : 87.70 %
# Accuracy of   car : 92.20 %
# Accuracy of  bird : 77.10 %
# Accuracy of   cat : 70.50 %
# Accuracy of  deer : 84.90 %
# Accuracy of   dog : 77.20 %
# Accuracy of  frog : 91.10 %
# Accuracy of horse : 89.50 %
# Accuracy of  ship : 92.40 %
# Accuracy of truck : 91.10 %
# 85.37
# [Epoch : 271, Iter:    50] loss: 1.599
# [Epoch : 272, Iter:    50] loss: 1.597
# [Epoch : 273, Iter:    50] loss: 1.597
# [Epoch : 274, Iter:    50] loss: 1.597
# [Epoch : 275, Iter:    50] loss: 1.597
# [Epoch : 276, Iter:    50] loss: 1.597
# [Epoch : 277, Iter:    50] loss: 1.598
# [Epoch : 278, Iter:    50] loss: 1.597
# [Epoch : 279, Iter:    50] loss: 1.597
# [Epoch : 280, Iter:    50] loss: 1.596
# Start test
# Accuracy of plane : 89.90 %
# Accuracy of   car : 93.10 %
# Accuracy of  bird : 78.20 %
# Accuracy of   cat : 68.40 %
# Accuracy of  deer : 86.50 %
# Accuracy of   dog : 75.20 %
# Accuracy of  frog : 90.90 %
# Accuracy of horse : 90.50 %
# Accuracy of  ship : 91.80 %
# Accuracy of truck : 90.80 %
# 85.53
# [Epoch : 281, Iter:    50] loss: 1.598
# [Epoch : 282, Iter:    50] loss: 1.596
# [Epoch : 283, Iter:    50] loss: 1.597
# [Epoch : 284, Iter:    50] loss: 1.599
# [Epoch : 285, Iter:    50] loss: 1.597
# [Epoch : 286, Iter:    50] loss: 1.597
# [Epoch : 287, Iter:    50] loss: 1.598
# [Epoch : 288, Iter:    50] loss: 1.597
# [Epoch : 289, Iter:    50] loss: 1.597
# [Epoch : 290, Iter:    50] loss: 1.597
# Start test
# Accuracy of plane : 88.90 %
# Accuracy of   car : 92.90 %
# Accuracy of  bird : 79.00 %
# Accuracy of   cat : 67.60 %
# Accuracy of  deer : 83.40 %
# Accuracy of   dog : 77.90 %
# Accuracy of  frog : 90.80 %
# Accuracy of horse : 90.30 %
# Accuracy of  ship : 91.90 %
# Accuracy of truck : 92.10 %
# 85.47999999999999
# [Epoch : 291, Iter:    50] loss: 1.597
# [Epoch : 292, Iter:    50] loss: 1.596
# [Epoch : 293, Iter:    50] loss: 1.596
# [Epoch : 294, Iter:    50] loss: 1.595
# [Epoch : 295, Iter:    50] loss: 1.597
# [Epoch : 296, Iter:    50] loss: 1.596
# [Epoch : 297, Iter:    50] loss: 1.596
# [Epoch : 298, Iter:    50] loss: 1.597
# [Epoch : 299, Iter:    50] loss: 1.596
# [Epoch : 300, Iter:    50] loss: 1.596
# Start test
# Accuracy of plane : 88.80 %
# Accuracy of   car : 93.20 %
# Accuracy of  bird : 76.60 %
# Accuracy of   cat : 70.40 %
# Accuracy of  deer : 85.70 %
# Accuracy of   dog : 76.00 %
# Accuracy of  frog : 90.80 %
# Accuracy of horse : 90.00 %
# Accuracy of  ship : 92.40 %
# Accuracy of truck : 90.90 %
# 85.47999999999999

# %%
sns.set()
epochs = [10 * i for i in range((30))]
plt.plot(epochs, net_scores[:30], label="Net_CDO")
plt.plot(epochs, net_scores[30:60], label="Net_VDO")
plt.plot(epochs, net_scores[60:], label="Net_MCDO")
plt.xlabel("epochs")
plt.ylabel("Test accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# %%
cdropout1_history = [cdropout_history[i][0] for i in range(30)]
cdropout2_history = [cdropout_history[i][1] for i in range(30)]
cdropout3_history = [cdropout_history[i][2] for i in range(30)]
cdropout4_history = [cdropout_history[i][3] for i in range(30)]

plt.plot(epochs, cdropout1_history, label="cdropout1")
plt.plot(epochs, cdropout2_history, label="cdropout2")
plt.plot(epochs, cdropout3_history, label="cdropout3")
plt.plot(epochs, cdropout4_history, label="cdropout4")
plt.xlabel("epochs")
plt.ylabel("Dropout rate")
plt.legend()
plt.tight_layout()
plt.show()

# %%
vdropout1_history = [vdropout_history[i][0] for i in range(30)]
vdropout2_history = [vdropout_history[i][1] for i in range(30)]
vdropout3_history = [vdropout_history[i][2] for i in range(30)]
vdropout4_history = [vdropout_history[i][3] for i in range(30)]

plt.plot(epochs, vdropout1_history, label="vdropout1")
plt.plot(epochs, vdropout2_history, label="vdropout2")
plt.plot(epochs, vdropout3_history, label="vdropout3")
plt.plot(epochs, vdropout4_history, label="vdropout4")
plt.xlabel("epochs")
plt.ylabel("Alpha value")
plt.legend()
plt.tight_layout()
plt.show()
